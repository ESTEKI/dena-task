# %%
import agent_src.agent as agent
TaskAgent = agent.Agent()
# Out:
# 2026-06-03 23:33:16,087 [Agent] [INFO] Graph compiled successfully.

# %%
تسکهای باز دپارتمان پشتیبانی را نشان بده

# %%
response = TaskAgent.tryInvoke(user_input="تسکهای باز محمد رضایی را نشان بده",userID="26w")
# Out:
# c:\ProgramData\anaconda3\envs\agenttask_py311\Lib\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(PydanticSerializationUnexpectedValue: Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=SearchNodeOutput(create_t...یی', department=None), input_type=SearchNodeOutput]
# PydanticSerializationUnexpectedValue: Expected `ResponseOutputRefusal` - serialized value may not be as expected [field_name='content', input_value=ParsedResponseOutputText[...یی', department=None)), input_type=ParsedResponseOutputText[~TextFormatT]])
#   PydanticSerializationUnexpectedValue(Expected `ParsedResponseFunctionToolCall` - serialized value may not be as expected [field_name='output', input_value=ParsedResponseOutputMessa...e='message', phase=None), input_type=ParsedResponseOutputMessage[~TextFormatT]])
# ...

# %%
response
# Out:
# {'messages': [HumanMessage(content='تسکهای باز محمد رضایی را نشان بده', additional_kwargs={}, response_metadata={}, id='4a11ac50-9d2a-4925-9280-9affe8bc3359')],
#  'user_intent': 'Search',
#  'search_criteria': {'status': 'Open', 'fullname': 'محمد رضایی'}}

# %%
response.get("messages")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response.get("messages")
#
# NameError: name 'response' is not defined
