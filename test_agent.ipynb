# %%
import agent_src.agent as agent


# I kept getting warnings that were not important (I think), so I disabled them all.
import warnings

warnings.filterwarnings(
    "ignore",
    module="pydantic"
)


TaskAgent = agent.Agent()
# Out:
# 2026-06-05 20:19:39,304 [Agent] [INFO] Graph compiled successfully.

# %%
TaskAgent.plot()

# %%
# I kept getting warnings that were not important (I think), so I disabled them all.
import warnings

warnings.filterwarnings(
    "ignore",
    module="pydantic"
)

# %%
response = TaskAgent.tryInvoke(user_input="تسکهای باز امیر عباسی را نشان بده",userID="26w")
# Out:
# User intent in orchestrator Node:Search
# <class 'agent_src.basemodels.SearchNodeOutput'>
# {'status': 'Open', 'fullname': 'امیر عباسی'}
# -----api call----------------
# PAYLOAD:
# {'search_criteria': {'create_time': None, 'status': 'Open', 'priority': None, 'due_time': None, 'fullname': 'امیر عباسی', 'department': None}, 'time_window': None}
# <class 'NoneType'>
# 200
# {"count":150,"data":[{"Unnamed: 0":0,"id":1,"title":"رفع باگ ورود کاربران","description":"بررسی و رفع خطای لاگین در نسخه وب","create_time":"2026-01-05","status":"Done","assignee_id":1,"priority":"High","due_time":"2026/01/08","fullname":"علی صابری","department":"فنی","create_year":2026,"create_month":1,"create_day":5},{"Unnamed: 0":1,"id":2,"title":"پیاده سازی API احراز هویت","description":"ایجاد سرویس JWT برای کاربران","create_time":"2026-01-07","status":"Done","assignee_id":2,"priority":"Critical","due_time":"2026/01/15","fullname":"رضا محمدی","department":"فنی","create_year":2026,"create_month":1,"create_day":7},{"Unnamed: 0":2,"id":3,"title":"طراحی داشبورد مدیریت","description":"طراحی اولیه داشبورد مدیران سیستم","create_time":"2026-01-10","status":"In Progress","assignee_id":3,"priority":"High","due_time":"2026/06/15","fullname":"سارا احمدی","department":"محصول","create_year":2026,"create_month":1,"create_day":10},{"Unnamed: 0":3,"id":4,"title":"تهیه گزارش مالی دی ماه","description":"آماده سازی گزارش هزینه های ماهانه","create_time":"2026-01-12","status":"Done","assignee_id":7,"priority":"Medium","due_time":"2026/01/20","fullname":"نرگس حسینی","department":"مالی","create_year":2026,"create_month":1,"create_day":12},{"Unnamed: 0":4,"id":5,"title":"پاسخگویی به تیکت های مشتریان","description":"بررسی تیکت های معوق","create_time":"2026-01-15","status":"Done","assignee_id":5,"priority":"Medium","due_time":"2026/01/18","fullname":"مریم کریمی","department":"پشتیبانی","create_year":2026,"create_month":1,"create_day":15},{"Unnamed: 0":5,"id":6,"title":"استقرار نسخه 2.1","description":"انتشار نسخه جدید روی سرور عملیاتی","create_time":"2026-01-16","status":"Done","assignee_id":6,"priority":"High","due_time":"2026/01/20","fullname":"حسین اکبری","department":"استقرار","create_year":2026,"create_month":1,"create_day":16},{"Unnamed: 0":6,"id":7,"title":"بازنگری Roadmap محصول","description":"بررسی برنامه سه ماه آینده","create_time":"2026-01-20","status":"Done","assignee_id":22,"priority":"High","due_time":"2026/01/30","fullname":"یاسمن کریمی","department":"محصول","create_year":2026,"create_month":1,"create_day":20},{"Unnamed: 0":7,"id":8,"title":"رفع مشکل مصرف حافظه","description":"بهینه سازی Memory Usage سرویس","create_time":"2026-01-21","status":"Done","assignee_id":8,"priority":"Critical","due_time":"2026/01/28","fullname":"امیر عباسی","department":"فنی","create_year":2026,"create_month":1,"create_day":21},{"Unnamed: 0":8,"id":9,"title":"طراحی صفحه پروفایل کاربر","description":"بهبود تجربه کاربری","create_time":"2026-01-22","status":"Review","assignee_id":9,"priority":"Medium","due_time":"2026/06/05","fullname":"زهرا موسوی","department":"محصول","create_year":2026,"create_month":1,"create_day":22},{"Unnamed: 0":9,"id":10,"title":"پیاده سازی سیستم اعلان","description":"ارسال Notification در سیستم","create_time":"2026-01-25","status":"In Progress","assignee_id":10,"priority":"High","due_time":"2026/06/10","fullname":"پیمان قاسمی","department":"فنی","create_year":2026,"create_month":1,"create_day":25},{"Unnamed: 0":10,"id":11,"title":"بررسی شکایات مشتریان","description":"تحلیل و پاسخ به شکایات ثبت شده","create_time":"2026-01-26","status":"Done","assignee_id":11,"priority":"Medium","due_time":"2026/02/01","fullname":"فاطمه رحیمی","department":"پشتیبانی","create_year":2026,"create_month":1,"create_day":26},{"Unnamed: 0":11,"id":12,"title":"استقرار محیط آزمایشی","description":"راه اندازی سرور تست جدید","create_time":"2026-01-28","status":"Done","assignee_id":12,"priority":"Medium","due_time":"2026/02/05","fullname":"سعید نادری","department":"استقرار","create_year":2026,"create_month":1,"create_day":28},{"Unnamed: 0":12,"id":13,"title":"جلسه برنامه ریزی فصلی","description":"هماهنگی اهداف فصل جدید","create_time":"2026-02-01","status":"Done","assignee_id":13,"priority":"Low","due_time":"2026/02/03","fullname":"محمدجواد کاظمی","department":"مدیریت","create_year":2026,"create_month":2,"create_day":1},{"Unnamed: 0":13,"id":14,"title":"کنترل هزینه های ...
# -----api call----------------
# API result: {'count': 150, 'data': [{'Unnamed: 0': 0, 'id': 1, 'title': 'رفع باگ ورود کاربران', 'description': 'بررسی و رفع خطای لاگین در نسخه وب', 'create_time': '2026-01-05', 'status': 'Done', 'assignee_id': 1, 'priority': 'High', 'due_time': '2026/01/08', 'fullname': 'علی صابری', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 5}, {'Unnamed: 0': 1, 'id': 2, 'title': 'پیاده سازی API احراز هویت', 'description': 'ایجاد سرویس JWT برای کاربران', 'create_time': '2026-01-07', 'status': 'Done', 'assignee_id': 2, 'priority': 'Critical', 'due_time': '2026/01/15', 'fullname': 'رضا محمدی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 7}, {'Unnamed: 0': 2, 'id': 3, 'title': 'طراحی داشبورد مدیریت', 'description': 'طراحی اولیه داشبورد مدیران سیستم', 'create_time': '2026-01-10', 'status': 'In Progress', 'assignee_id': 3, 'priority': 'High', 'due_time': '2026/06/15', 'fullname': 'سارا احمدی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 10}, {'Unnamed: 0': 3, 'id': 4, 'title': 'تهیه گزارش مالی دی ماه', 'description': 'آماده سازی گزارش هزینه های ماهانه', 'create_time': '2026-01-12', 'status': 'Done', 'assignee_id': 7, 'priority': 'Medium', 'due_time': '2026/01/20', 'fullname': 'نرگس حسینی', 'department': 'مالی', 'create_year': 2026, 'create_month': 1, 'create_day': 12}, {'Unnamed: 0': 4, 'id': 5, 'title': 'پاسخگویی به تیکت های مشتریان', 'description': 'بررسی تیکت های معوق', 'create_time': '2026-01-15', 'status': 'Done', 'assignee_id': 5, 'priority': 'Medium', 'due_time': '2026/01/18', 'fullname': 'مریم کریمی', 'department': 'پشتیبانی', 'create_year': 2026, 'create_month': 1, 'create_day': 15}, {'Unnamed: 0': 5, 'id': 6, 'title': 'استقرار نسخه 2.1', 'description': 'انتشار نسخه جدید روی سرور عملیاتی', 'create_time': '2026-01-16', 'status': 'Done', 'assignee_id': 6, 'priority': 'High', 'due_time': '2026/01/20', 'fullname': 'حسین اکبری', 'department': 'استقرار', 'create_year': 2026, 'create_month': 1, 'create_day': 16}, {'Unnamed: 0': 6, 'id': 7, 'title': 'بازنگری Roadmap محصول', 'description': 'بررسی برنامه سه ماه آینده', 'create_time': '2026-01-20', 'status': 'Done', 'assignee_id': 22, 'priority': 'High', 'due_time': '2026/01/30', 'fullname': 'یاسمن کریمی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 20}, {'Unnamed: 0': 7, 'id': 8, 'title': 'رفع مشکل مصرف حافظه', 'description': 'بهینه سازی Memory Usage سرویس', 'create_time': '2026-01-21', 'status': 'Done', 'assignee_id': 8, 'priority': 'Critical', 'due_time': '2026/01/28', 'fullname': 'امیر عباسی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 21}, {'Unnamed: 0': 8, 'id': 9, 'title': 'طراحی صفحه پروفایل کاربر', 'description': 'بهبود تجربه کاربری', 'create_time': '2026-01-22', 'status': 'Review', 'assignee_id': 9, 'priority': 'Medium', 'due_time': '2026/06/05', 'fullname': 'زهرا موسوی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 22}, {'Unnamed: 0': 9, 'id': 10, 'title': 'پیاده سازی سیستم اعلان', 'description': 'ارسال Notification در سیستم', 'create_time': '2026-01-25', 'status': 'In Progress', 'assignee_id': 10, 'priority': 'High', 'due_time': '2026/06/10', 'fullname': 'پیمان قاسمی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 25}, {'Unnamed: 0': 10, 'id': 11, 'title': 'بررسی شکایات مشتریان', 'description': 'تحلیل و پاسخ به شکایات ثبت شده', 'create_time': '2026-01-26', 'status': 'Done', 'assignee_id': 11, 'priority': 'Medium', 'due_time': '2026/02/01', 'fullname': 'فاطمه رحیمی', 'department': 'پشتیبانی', 'create_year': 2026, 'create_month': 1, 'create_day': 26}, {'Unnamed: 0': 11, 'id': 12, 'title': 'استقرار محیط آزمایشی', 'description': 'راه اندازی سرور تست جدید', 'create_time': '2026-01-28', 'status': 'Done', 'assignee_id': 12, 'priority': 'Medium', 'due_time': '2026/02/05', 'fullname': 'سعید نادری', 'department': 'استقرار', 'create_year': 2026, 'create_month': 1, 'create_day': 28 ...
# User is asking for Search about the ticketing system data. And the total found number is 150
# تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.
# کاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.
# کاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:
#
# 1- Statistics - به معنی آماری
# 2- Analytical - تحلیلی
# 3- Search - جستجو
# 4- Operation - به معنی اعمال هرگونه تغییر
#
#
# در صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.
#
# در صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی.
#  اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد.
#  (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)
#
#
# ** Important: and here is the user intent that you receive:
# User is asking for Search about the ticketing system data. And the total found number is 150
# You should generate an appropriate response to the user based on the conversation history.
#
# Formatted prompt for CHAT node:
# [SystemMessage(content='تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.\nکاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.\nکاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:\n\n1- Statistics - به معنی آماری\n2- Analytical - تحلیلی\n3- Search - جستجو\n4- Operation - به معنی اعمال هرگونه تغییر \n\n\nدر صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.\n\nدر صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی. \n اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد. \n (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)\n\n\n** Important: and here is the user intent that you receive:\nUser is asking for Search about the ticketing system data. And the total found number is 150\nYou should generate an appropriate response to the user based on the conversation history.\n ', additional_kwargs={}, response_metadata={}), HumanMessage(content='تسکهای باز امیر عباسی را نشان بده', additional_kwargs={}, response_metadata={}, id='2b8f1415-b7b5-42f3-af98-135b47f90b5b')]
# LLM response for chat node:
# content=[{'id': 'resp_01ktc56z5beybsaszk24kdh21t', 'summary': [], 'type': 'reasoning', 'content': [{'text': 'User wants search. So respond: items sent.', 'type': 'reasoning_text'}], 'status': 'completed'}, {'type': 'text', 'text': 'موارد پیدا شده برای شما ارسال شد.', 'annotations': [], 'id': 'msg_01ktc56z5beyc8qycgx29rmhhd'}] additional_kwargs={} response_metadata={'id': 'resp_01ktc56z5beybbrkcsahz1d78t', 'created_at': 1780672068.0, 'metadata': {}, 'model': 'openai/gpt-oss-120b', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b'} id='resp_01ktc56z5beybbrkcsahz1d78t' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 380, 'output_tokens': 29, 'total_tokens': 409, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 11}}
# Chat response: موارد پیدا شده برای شما ارسال شد.
# 2026-06-05 18:37:49,273 [Agent] [INFO] Graph response: {'messages': [HumanMessage(content='تسکهای باز امیر عباسی را نشان بده', additional_kwargs={}, response_metadata={}, id='2b8f1415-b7b5-42f3-af98-135b47f90b5b'), AIMessage(content='موارد پیدا شده برای شما ارسال شد.', additional_kwargs={}, response_metadata={}, id='e1a8f442-2d8d-4741-a2fa-b95e0acde827', tool_calls=[], invalid_tool_calls=[])], 'user_intent': 'Search', 'search_criteria': {'create_time': None, 'status': 'Open', 'priority': None, 'due_time': None, 'fullname': 'امیر عباسی', 'department': None}, 'retrieved_data': {'count': 150, 'data': [{'Unnamed: 0': 0, 'id': 1, 'title': 'رفع باگ ورود کاربران', 'description': 'بررسی و رفع خطای لاگین در نسخه وب', 'create_time': '2026-01-05', 'status': 'Done', 'assignee_id': 1, 'priority': 'High', 'due_time': '2026/01/08', 'fullname': 'علی صابری', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 5}, {'Unnamed: 0': 1, 'id': 2, 'title': 'پیاده سازی API احراز هویت', 'description': 'ایجاد سرویس JWT برای کاربران', 'create_time': '2026-01-07', 'status': 'Done', 'assignee_id': 2, 'priority': 'Critical', 'due_time': '2026/01/15', 'fullname': 'رضا محمدی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 7}, {'Unnamed: 0': 2, 'id': 3, 'title': 'طراحی داشبورد مدیریت', 'description': 'طراحی اولیه داشبورد مدیران سیستم', 'create_time': '2026-01-10', 'status': 'In Progress', 'assignee_id': 3, 'priority': 'High', 'due_time': '2026/06/15', 'fullname': 'سارا احمدی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 10}, {'Unnamed: 0': 3, 'id': 4, 'title': 'تهیه گزارش مالی دی ماه', 'description': 'آماده سازی گزارش هزینه های ماهانه', 'create_time': '2026-01-12', 'status': 'Done', 'assignee_id': 7, 'priority': 'Medium', 'due_time': '2026/01/20', 'fullname': 'نرگس حسینی', 'department': 'مالی', 'create_year': 2026, 'create_month': 1, 'create_day': 12}, {'Unnamed: 0': 4, 'id': 5, 'title': 'پاسخگویی به تیکت های مشتریان', 'description': 'بررسی تیکت های معوق', 'create_time': '2026-01-15', 'status': 'Done', 'assignee_id': 5, 'priority': 'Medium', 'due_time': '2026/01/18', 'fullname': 'مریم کریمی', 'department': 'پشتیبانی', 'create_year': 2026, 'create_month': 1, 'create_day': 15}, {'Unnamed: 0': 5, 'id': 6, 'title': 'استقرار نسخه 2.1', 'description': 'انتشار نسخه جدید روی سرور عملیاتی', 'create_time': '2026-01-16', 'status': 'Done', 'assignee_id': 6, 'priority': 'High', 'due_time': '2026/01/20', 'fullname': 'حسین اکبری', 'department': 'استقرار', 'create_year': 2026, 'create_month': 1, 'create_day': 16}, {'Unnamed: 0': 6, 'id': 7, 'title': 'بازنگری Roadmap محصول', 'description': 'بررسی برنامه سه ماه آینده', 'create_time': '2026-01-20', 'status': 'Done', 'assignee_id': 22, 'priority': 'High', 'due_time': '2026/01/30', 'fullname': 'یاسمن کریمی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 20}, {'Unnamed: 0': 7, 'id': 8, 'title': 'رفع مشکل مصرف حافظه', 'description': 'بهینه سازی Memory Usage سرویس', 'create_time': '2026-01-21', 'status': 'Done', 'assignee_id': 8, 'priority': 'Critical', 'due_time': '2026/01/28', 'fullname': 'امیر عباسی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 21}, {'Unnamed: 0': 8, 'id': 9, 'title': 'طراحی صفحه پروفایل کاربر', 'description': 'بهبود تجربه کاربری', 'create_time': '2026-01-22', 'status': 'Review', 'assignee_id': 9, 'priority': 'Medium', 'due_time': '2026/06/05', 'fullname': 'زهرا موسوی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 22}, {'Unnamed: 0': 9, 'id': 10, 'title': 'پیاده سازی سیستم اعلان', 'description': 'ارسال Notification در سیستم', 'create_time': '2026-01-25', 'status': 'In Progress', 'assignee_id': 10, 'priority': 'High', 'due_time': '2026/06/10', 'fullname': 'پیمان قاسمی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 25}, {'Unnamed: 0': 10, 'id': 11, 'title': 'بررسی شکایات مشتریان', 'description': 'تحلیل و پاسخ به ...

# %%
response
# Out:
# {'messages': [HumanMessage(content='تسکهای باز امیر عباسی را نشان بده', additional_kwargs={}, response_metadata={}, id='2b8f1415-b7b5-42f3-af98-135b47f90b5b'),
#   AIMessage(content='موارد پیدا شده برای شما ارسال شد.', additional_kwargs={}, response_metadata={}, id='e1a8f442-2d8d-4741-a2fa-b95e0acde827', tool_calls=[], invalid_tool_calls=[])],
#  'user_intent': 'Search',
#  'search_criteria': {'create_time': None,
#   'status': 'Open',
#   'priority': None,
#   'due_time': None,
#   'fullname': 'امیر عباسی',
#   'department': None},
#  'retrieved_data': {'count': 150,
#   'data': [{'Unnamed: 0': 0,
#     'id': 1,
#     'title': 'رفع باگ ورود کاربران',
#     'description': 'بررسی و رفع خطای لاگین در نسخه وب',
#     'create_time': '2026-01-05',
#     'status': 'Done',
#     'assignee_id': 1,
#     'priority': 'High',
#     'due_time': '2026/01/08',
#     'fullname': 'علی صابری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 5},
#    {'Unnamed: 0': 1,
#     'id': 2,
#     'title': 'پیاده سازی API احراز هویت',
#     'description': 'ایجاد سرویس JWT برای کاربران',
#     'create_time': '2026-01-07',
#     'status': 'Done',
#     'assignee_id': 2,
#     'priority': 'Critical',
#     'due_time': '2026/01/15',
#     'fullname': 'رضا محمدی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 7},
#    {'Unnamed: 0': 2,
#     'id': 3,
#     'title': 'طراحی داشبورد مدیریت',
#     'description': 'طراحی اولیه داشبورد مدیران سیستم',
#     'create_time': '2026-01-10',
#     'status': 'In Progress',
#     'assignee_id': 3,
#     'priority': 'High',
#     'due_time': '2026/06/15',
#     'fullname': 'سارا احمدی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 10},
#    {'Unnamed: 0': 3,
#     'id': 4,
#     'title': 'تهیه گزارش مالی دی ماه',
#     'description': 'آماده سازی گزارش هزینه های ماهانه',
#     'create_time': '2026-01-12',
#     'status': 'Done',
#     'assignee_id': 7,
#     'priority': 'Medium',
#     'due_time': '2026/01/20',
#     'fullname': 'نرگس حسینی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 12},
#    {'Unnamed: 0': 4,
#     'id': 5,
#     'title': 'پاسخگویی به تیکت های مشتریان',
#     'description': 'بررسی تیکت های معوق',
#     'create_time': '2026-01-15',
#     'status': 'Done',
#     'assignee_id': 5,
#     'priority': 'Medium',
#     'due_time': '2026/01/18',
#     'fullname': 'مریم کریمی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 15},
#    {'Unnamed: 0': 5,
#     'id': 6,
#     'title': 'استقرار نسخه 2.1',
#     'description': 'انتشار نسخه جدید روی سرور عملیاتی',
#     'create_time': '2026-01-16',
#     'status': 'Done',
#     'assignee_id': 6,
#     'priority': 'High',
#     'due_time': '2026/01/20',
#     'fullname': 'حسین اکبری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 16},
#    {'Unnamed: 0': 6,
#     'id': 7,
#     'title': 'بازنگری Roadmap محصول',
#     'description': 'بررسی برنامه سه ماه آینده',
#     'create_time': '2026-01-20',
#     'status': 'Done',
#     'assignee_id': 22,
#     'priority': 'High',
#     'due_time': '2026/01/30',
#     'fullname': 'یاسمن کریمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 20},
#    {'Unnamed: 0': 7,
#     'id': 8,
#     'title': 'رفع مشکل مصرف حافظه',
#     'description': 'بهینه سازی Memory Usage سرویس',
#     'create_time': '2026-01-21',
#     'status': 'Done',
#     'assignee_id': 8,
#     'priority': 'Critical',
#     'due_time': '2026/01/28',
#     'fullname': 'امیر عباسی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 21},
#    {'Unnamed: 0': 8,
#     'id': 9,
#     'title': 'طراحی صفحه پروفایل کاربر',
#     'description': 'بهبود تجربه کاربری',
#     'create_time': '2026-01-22',
#     'status': 'Review',
#     'assignee_id': 9,
#     'priority': 'Medium',
#     'due_time': '2026/06/05',
#     'fullname': 'زهرا موسوی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 22},
#    {'Unnamed: 0': 9,
#     'id': 10,
#     'title': 'پیاده سازی سیستم اعلان',
#     'description': 'ارسال Notification در سیستم',
#     'create_time': '2026-01-25',
#     'status': 'In Progress',
#     'assignee_id': 10,
#     'priority': 'High',
#     'due_time': '2026/06/10',
#     'fullname': 'پیمان قاسمی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 25},
#    {'Unnamed: 0': 10,
#     'id': 11,
#     'title': 'بررسی شکایات مشتریان',
#     'description': 'تحلیل و پاسخ به شکایات ثبت شده',
#     'create_time': '2026-01-26',
#     'status': 'Done',
#     'assignee_id': 11,
#     'priority': 'Medium',
#     'due_time': '2026/02/01',
#     'fullname': 'فاطمه رحیمی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 26},
#    {'Unnamed: 0': 11,
#     'id': 12,
#     'title': 'استقرار محیط آزمایشی',
#     'description': 'راه اندازی سرور تست جدید',
#     'create_time': '2026-01-28',
#     'status': 'Done',
#     'assignee_id': 12,
#     'priority': 'Medium',
#     'due_time': '2026/02/05',
#     'fullname': 'سعید نادری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 28},
#    {'Unnamed: 0': 12,
#     'id': 13,
#     'title': 'جلسه برنامه ریزی فصلی',
#     'description': 'هماهنگی اهداف فصل جدید',
#     'create_time': '2026-02-01',
#     'status': 'Done',
#     'assignee_id': 13,
#     'priority': 'Low',
#     'due_time': '2026/02/03',
#     'fullname': 'محمدجواد کاظمی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 1},
#    {'Unnamed: 0': 13,
#     'id': 14,
#     'title': 'کنترل هزینه های پروژه',
#     'description': 'بررسی هزینه های زیرساخت',
#     'create_time': '2026-02-02',
#     'status': 'Done',
#     'assignee_id': 14,
#     'priority': 'Medium',
#     'due_time': '2026/02/10',
#     'fullname': 'لیلا جعفری',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 2},
#    {'Unnamed: 0': 14,
#     'id': 15,
#     'title': 'توسعه ماژول گزارش گیری',
#     'description': 'ایجاد گزارش های مدیریتی',
#     'create_time': '2026-02-05',
#     'status': 'In Progress',
#     'assignee_id': 15,
#     'priority': 'High',
#     'due_time': '2026/06/20',
#     'fullname': 'علی مرادی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 5},
#    {'Unnamed: 0': 15,
#     'id': 16,
#     'title': 'تحلیل نیازمندی های نسخه جدید',
#     'description': 'جمع آوری نیازهای مشتریان',
#     'create_time': '2026-02-07',
#     'status': 'Done',
#     'assignee_id': 16,
#     'priority': 'Medium',
#     'due_time': '2026/02/20',
#     'fullname': 'الهام رستمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 7},
#    {'Unnamed: 0': 16,
#     'id': 17,
#     'title': 'مهاجرت سرور فایل',
#     'description': 'انتقال داده ها به سرور جدید',
#     'create_time': '2026-02-10',
#     'status': 'Done',
#     'assignee_id': 17,
#     'priority': 'Critical',
#     'due_time': '2026/02/18',
#     'fullname': 'مجتبی حیدری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 10},
#    {'Unnamed: 0': 17,
#     'id': 18,
#     'title': 'بررسی SLA پشتیبانی',
#     'description': 'تحلیل عملکرد تیم پشتیبانی',
#     'create_time': '2026-02-11',
#     'status': 'Done',
#     'assignee_id': 18,
#     'priority': 'Medium',
#     'due_time': '2026/02/25',
#     'fullname': 'نگار امینی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 11},
#    {'Unnamed: 0': 18,
#     'id': 19,
#     'title': 'رفع خطای گزارش فروش',
#     'description': 'اصلاح محاسبات گزارش ها',
#     'create_time': '2026-02-14',
#     'status': 'Done',
#     'assignee_id': 19,
#     'priority': 'High',
#     'due_time': '2026/02/20',
#     'fullname': 'احمد صادقی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 14},
#    {'Unnamed: 0': 19,
#     'id': 20,
#     'title': 'تهیه گزارش مالی بهمن',
#     'description': 'آماده سازی گزارش مالی ماهانه',
#     'create_time': '2026-02-15',
#     'status': 'Done',
#     'assignee_id': 20,
#     'priority': 'Medium',
#     'due_time': '2026/02/28',
#     'fullname': 'سمیه شریفی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 15},
#    {'Unnamed: 0': 20,
#     'id': 21,
#     'title': 'بررسی عملکرد تیم ها',
#     'description': 'ارزیابی KPI واحدها',
#     'create_time': '2026-02-18',
#     'status': 'Done',
#     'assignee_id': 21,
#     'priority': 'Low',
#     'due_time': '2026/03/01',
#     'fullname': 'مهدی قنبری',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 18},
#    {'Unnamed: 0': 21,
#     'id': 22,
#     'title': 'طراحی فرآیند ثبت درخواست',
#     'description': 'بهبود فرآیندهای داخلی',
#     'create_time': '2026-02-20',
#     'status': 'Done',
#     'assignee_id': 22,
#     'priority': 'Medium',
#     'due_time': '2026/03/05',
#     'fullname': 'یاسمن کریمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 20},
#    {'Unnamed: 0': 22,
#     'id': 23,
#     'title': 'پیاده سازی جستجوی پیشرفته',
#     'description': 'افزودن قابلیت فیلتر و جستجو',
#     'create_time': '2026-02-22',
#     'status': 'Review',
#     'assignee_id': 23,
#     'priority': 'High',
#     'due_time': '2026/06/08',
#     'fullname': 'محمد صالحی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 22},
#    {'Unnamed: 0': 23,
#     'id': 24,
#     'title': 'پاسخ به مشتریان سازمانی',
#     'description': 'پیگیری درخواست های ویژه',
#     'create_time': '2026-02-24',
#     'status': 'Done',
#     'assignee_id': 24,
#     'priority': 'Medium',
#     'due_time': '2026/03/03',
#     'fullname': 'زینب نوری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 24},
#    {'Unnamed: 0': 24,
#     'id': 25,
#     'title': 'استقرار سرویس پیامک',
#     'description': 'راه اندازی سرویس ارسال پیامک',
#     'create_time': '2026-02-25',
#     'status': 'Done',
#     'assignee_id': 25,
#     'priority': 'High',
#     'due_time': '2026/03/05',
#     'fullname': 'امین توکلی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 25},
#    {'Unnamed: 0': 25,
#     'id': 26,
#     'title': 'بررسی مغایرت مالی',
#     'description': 'تحلیل تراکنش های ثبت شده',
#     'create_time': '2026-02-26',
#     'status': 'Done',
#     'assignee_id': 26,
#     'priority': 'Medium',
#     'due_time': '2026/03/06',
#     'fullname': 'هانیه یوسفی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 2,
#     'create_day': 26},
#    {'Unnamed: 0': 26,
#     'id': 27,
#     'title': 'بهینه سازی کوئری های دیتابیس',
#     'description': 'کاهش زمان پاسخگویی سیستم',
#     'create_time': '2026-03-01',
#     'status': 'In Progress',
#     'assignee_id': 27,
#     'priority': 'Critical',
#     'due_time': '2026/06/12',
#     'fullname': 'علیرضا محمدپور',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 1},
#    {'Unnamed: 0': 27,
#     'id': 28,
#     'title': 'تحلیل رفتار کاربران',
#     'description': 'بررسی داده های استفاده از محصول',
#     'create_time': '2026-03-02',
#     'status': 'Done',
#     'assignee_id': 28,
#     'priority': 'Medium',
#     'due_time': '2026/03/15',
#     'fullname': 'پرستو زمانی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 2},
#    {'Unnamed: 0': 28,
#     'id': 29,
#     'title': 'پیاده سازی کش Redis',
#     'description': 'افزایش سرعت سرویس ها',
#     'create_time': '2026-03-04',
#     'status': 'Review',
#     'assignee_id': 29,
#     'priority': 'High',
#     'due_time': '2026/06/07',
#     'fullname': 'آرش دهقانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 4},
#    {'Unnamed: 0': 29,
#     'id': 30,
#     'title': 'بررسی تیکت های بحرانی',
#     'description': 'اولویت بندی مشکلات مشتریان',
#     'create_time': '2026-03-05',
#     'status': 'Done',
#     'assignee_id': 30,
#     'priority': 'High',
#     'due_time': '2026/03/08',
#     'fullname': 'نسرین باقری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 5},
#    {'Unnamed: 0': 30,
#     'id': 31,
#     'title': 'استقرار مانیتورینگ جدید',
#     'description': 'راه اندازی Prometheus و Grafana',
#     'create_time': '2026-03-06',
#     'status': 'Done',
#     'assignee_id': 31,
#     'priority': 'High',
#     'due_time': '2026/03/15',
#     'fullname': 'رضا نیکخواه',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 6},
#    {'Unnamed: 0': 31,
#     'id': 32,
#     'title': 'تهیه بودجه فصل دوم',
#     'description': 'برنامه ریزی مالی سه ماه آینده',
#     'create_time': '2026-03-08',
#     'status': 'Done',
#     'assignee_id': 32,
#     'priority': 'Medium',
#     'due_time': '2026/03/20',
#     'fullname': 'مونا سلیمانی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 8},
#    {'Unnamed: 0': 32,
#     'id': 33,
#     'title': 'بازنگری ساختار سازمانی',
#     'description': 'بررسی نیازهای توسعه تیم',
#     'create_time': '2026-03-10',
#     'status': 'Done',
#     'assignee_id': 33,
#     'priority': 'Low',
#     'due_time': '2026/03/25',
#     'fullname': 'حامد اسدی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 10},
#    {'Unnamed: 0': 33,
#     'id': 34,
#     'title': 'طراحی قابلیت اشتراک گذاری',
#     'description': 'تعریف سناریوهای محصول',
#     'create_time': '2026-03-12',
#     'status': 'Done',
#     'assignee_id': 34,
#     'priority': 'Medium',
#     'due_time': '2026/03/28',
#     'fullname': 'فرزانه رفیعی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 12},
#    {'Unnamed: 0': 34,
#     'id': 35,
#     'title': 'توسعه API گزارشات',
#     'description': 'افزودن Endpoint های جدید',
#     'create_time': '2026-03-15',
#     'status': 'In Progress',
#     'assignee_id': 35,
#     'priority': 'High',
#     'due_time': '2026/06/18',
#     'fullname': 'احسان طاهری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 15},
#    {'Unnamed: 0': 35,
#     'id': 36,
#     'title': 'پیگیری مشکلات مشتریان VIP',
#     'description': 'رسیدگی به مشتریان کلیدی',
#     'create_time': '2026-03-16',
#     'status': 'Done',
#     'assignee_id': 36,
#     'priority': 'High',
#     'due_time': '2026/03/22',
#     'fullname': 'مهسا نعمتی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 16},
#    {'Unnamed: 0': 36,
#     'id': 37,
#     'title': 'استقرار نسخه موبایل',
#     'description': 'انتشار نسخه Android جدید',
#     'create_time': '2026-03-18',
#     'status': 'Done',
#     'assignee_id': 37,
#     'priority': 'Critical',
#     'due_time': '2026/03/25',
#     'fullname': 'میلاد فتحی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 18},
#    {'Unnamed: 0': 37,
#     'id': 38,
#     'title': 'ممیزی مالی پروژه ها',
#     'description': 'کنترل هزینه های جاری',
#     'create_time': '2026-03-20',
#     'status': 'Done',
#     'assignee_id': 38,
#     'priority': 'Medium',
#     'due_time': '2026/03/30',
#     'fullname': 'شیوا محمودی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 20},
#    {'Unnamed: 0': 38,
#     'id': 39,
#     'title': 'رفع باگ API پرداخت',
#     'description': 'اصلاح خطای ثبت تراکنش',
#     'create_time': '2026-03-22',
#     'status': 'Done',
#     'assignee_id': 39,
#     'priority': 'Critical',
#     'due_time': '2026/03/28',
#     'fullname': 'پویا شهبازی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 22},
#    {'Unnamed: 0': 39,
#     'id': 40,
#     'title': 'تحلیل نرخ تبدیل کاربران',
#     'description': 'بررسی Funnel محصول',
#     'create_time': '2026-03-25',
#     'status': 'Done',
#     'assignee_id': 40,
#     'priority': 'Medium',
#     'due_time': '2026/04/05',
#     'fullname': 'سحر جلالی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 25},
#    {'Unnamed: 0': 40,
#     'id': 41,
#     'title': 'پیاده سازی سیستم RBAC',
#     'description': 'مدیریت سطح دسترسی کاربران',
#     'create_time': '2026-03-28',
#     'status': 'Open',
#     'assignee_id': 41,
#     'priority': 'High',
#     'due_time': '2026/06/25',
#     'fullname': 'داوود قربانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 3,
#     'create_day': 28},
#    {'Unnamed: 0': 41,
#     'id': 42,
#     'title': 'بررسی رضایت مشتریان',
#     'description': 'تحلیل نتایج نظرسنجی',
#     'create_time': '2026-04-01',
#     'status': 'In Progress',
#     'assignee_id': 42,
#     'priority': 'Medium',
#     'due_time': '2026/06/15',
#     'fullname': 'محدثه ملکی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 1},
#    {'Unnamed: 0': 42,
#     'id': 43,
#     'title': 'استقرار کلاستر جدید',
#     'description': 'افزایش ظرفیت زیرساخت',
#     'create_time': '2026-04-02',
#     'status': 'Open',
#     'assignee_id': 43,
#     'priority': 'Critical',
#     'due_time': '2026/06/12',
#     'fullname': 'مرتضی کریمی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 2},
#    {'Unnamed: 0': 43,
#     'id': 44,
#     'title': 'تهیه گزارش حسابرسی',
#     'description': 'جمع بندی مستندات مالی',
#     'create_time': '2026-04-05',
#     'status': 'Review',
#     'assignee_id': 44,
#     'priority': 'High',
#     'due_time': '2026/06/06',
#     'fullname': 'نازنین ابراهیمی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 5},
#    {'Unnamed: 0': 44,
#     'id': 45,
#     'title': 'برنامه ریزی استخدام تابستان',
#     'description': 'تعیین نیازهای جذب نیرو',
#     'create_time': '2026-04-07',
#     'status': 'Open',
#     'assignee_id': 45,
#     'priority': 'Medium',
#     'due_time': '2026/06/20',
#     'fullname': 'کیوان صادقی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 7},
#    {'Unnamed: 0': 45,
#     'id': 46,
#     'title': 'طراحی سیستم امتیازدهی کاربران',
#     'description': 'تعریف قوانین و سناریوها',
#     'create_time': '2026-04-10',
#     'status': 'Open',
#     'assignee_id': 46,
#     'priority': 'High',
#     'due_time': '2026/06/22',
#     'fullname': 'آرزو حسینی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 10},
#    {'Unnamed: 0': 46,
#     'id': 47,
#     'title': 'توسعه Agent هوش مصنوعی',
#     'description': 'پیاده سازی Agent سازمانی',
#     'create_time': '2026-04-12',
#     'status': 'In Progress',
#     'assignee_id': 47,
#     'priority': 'Critical',
#     'due_time': '2026/06/30',
#     'fullname': 'یوسف رحمانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 12},
#    {'Unnamed: 0': 47,
#     'id': 48,
#     'title': 'رسیدگی به تیکت های باز',
#     'description': 'کاهش حجم تیکت های معوق',
#     'create_time': '2026-04-15',
#     'status': 'Open',
#     'assignee_id': 48,
#     'priority': 'Medium',
#     'due_time': '2026/06/18',
#     'fullname': 'الهه اکبری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 15},
#    {'Unnamed: 0': 48,
#     'id': 49,
#     'title': 'استقرار سرویس پردازش فایل',
#     'description': 'راه اندازی سرویس جدید',
#     'create_time': '2026-04-18',
#     'status': 'Open',
#     'assignee_id': 49,
#     'priority': 'High',
#     'due_time': '2026/06/28',
#     'fullname': 'بهنام شفیعی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 18},
#    {'Unnamed: 0': 49,
#     'id': 50,
#     'title': 'تهیه گزارش مالی سه ماهه',
#     'description': 'آماده سازی گزارش مدیریتی',
#     'create_time': '2026-04-20',
#     'status': 'In Progress',
#     'assignee_id': 50,
#     'priority': 'Medium',
#     'due_time': '2026/06/15',
#     'fullname': 'رویا موسوی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 20},
#    {'Unnamed: 0': 50,
#     'id': 51,
#     'title': 'پیاده سازی لاگ متمرکز',
#     'description': 'تجمیع لاگ سرویس ها در زیرساخت مرکزی',
#     'create_time': '2026-04-21',
#     'status': 'In Progress',
#     'assignee_id': 1,
#     'priority': 'High',
#     'due_time': '2026/06/20',
#     'fullname': 'علی صابری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 21},
#    {'Unnamed: 0': 51,
#     'id': 52,
#     'title': 'بهینه سازی سرویس کاربران',
#     'description': 'کاهش زمان پاسخ API کاربران',
#     'create_time': '2026-04-22',
#     'status': 'Review',
#     'assignee_id': 2,
#     'priority': 'High',
#     'due_time': '2026/06/10',
#     'fullname': 'رضا محمدی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 22},
#    {'Unnamed: 0': 52,
#     'id': 53,
#     'title': 'طراحی فرآیند آنبوردینگ مشتری',
#     'description': 'مستندسازی مراحل ورود مشتری جدید',
#     'create_time': '2026-04-23',
#     'status': 'Done',
#     'assignee_id': 3,
#     'priority': 'Medium',
#     'due_time': '2026/05/05',
#     'fullname': 'سارا احمدی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 23},
#    {'Unnamed: 0': 53,
#     'id': 54,
#     'title': 'بازنگری اهداف فصل دوم',
#     'description': 'بررسی شاخص های عملکرد سازمان',
#     'create_time': '2026-04-24',
#     'status': 'Done',
#     'assignee_id': 4,
#     'priority': 'Low',
#     'due_time': '2026/05/01',
#     'fullname': 'محمد رضایی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 24},
#    {'Unnamed: 0': 54,
#     'id': 55,
#     'title': 'بررسی تیکت های SLA نقض شده',
#     'description': 'تحلیل موارد خارج از توافق سطح خدمت',
#     'create_time': '2026-04-25',
#     'status': 'Done',
#     'assignee_id': 5,
#     'priority': 'Medium',
#     'due_time': '2026/05/03',
#     'fullname': 'مریم کریمی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 25},
#    {'Unnamed: 0': 55,
#     'id': 56,
#     'title': 'استقرار سرویس گزارش گیری',
#     'description': 'انتشار سرویس جدید در محیط عملیاتی',
#     'create_time': '2026-04-26',
#     'status': 'Done',
#     'assignee_id': 6,
#     'priority': 'High',
#     'due_time': '2026/05/04',
#     'fullname': 'حسین اکبری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 26},
#    {'Unnamed: 0': 56,
#     'id': 57,
#     'title': 'تحلیل هزینه زیرساخت ابری',
#     'description': 'بررسی مصرف منابع و هزینه ها',
#     'create_time': '2026-04-27',
#     'status': 'Done',
#     'assignee_id': 7,
#     'priority': 'Medium',
#     'due_time': '2026/05/10',
#     'fullname': 'نرگس حسینی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 27},
#    {'Unnamed: 0': 57,
#     'id': 58,
#     'title': 'پیاده سازی Rate Limiting',
#     'description': 'افزودن محدودیت نرخ درخواست ها',
#     'create_time': '2026-04-28',
#     'status': 'Open',
#     'assignee_id': 8,
#     'priority': 'High',
#     'due_time': '2026/06/25',
#     'fullname': 'امیر عباسی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 28},
#    {'Unnamed: 0': 58,
#     'id': 59,
#     'title': 'طراحی صفحه تنظیمات حساب',
#     'description': 'تعریف تجربه کاربری جدید',
#     'create_time': '2026-04-29',
#     'status': 'Review',
#     'assignee_id': 9,
#     'priority': 'Medium',
#     'due_time': '2026/06/08',
#     'fullname': 'زهرا موسوی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 29},
#    {'Unnamed: 0': 59,
#     'id': 60,
#     'title': 'توسعه سرویس ارسال ایمیل',
#     'description': 'پیاده سازی Email Service مستقل',
#     'create_time': '2026-05-01',
#     'status': 'In Progress',
#     'assignee_id': 10,
#     'priority': 'High',
#     'due_time': '2026/06/18',
#     'fullname': 'پیمان قاسمی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 1},
#    {'Unnamed: 0': 60,
#     'id': 61,
#     'title': 'رسیدگی به درخواست های ویژه مشتریان',
#     'description': 'پیگیری نیازهای اختصاصی',
#     'create_time': '2026-05-02',
#     'status': 'Done',
#     'assignee_id': 11,
#     'priority': 'Medium',
#     'due_time': '2026/05/12',
#     'fullname': 'فاطمه رحیمی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 2},
#    {'Unnamed: 0': 61,
#     'id': 62,
#     'title': 'استقرار نسخه پشتیبان سیستم',
#     'description': 'راه اندازی محیط Disaster Recovery',
#     'create_time': '2026-05-03',
#     'status': 'Done',
#     'assignee_id': 12,
#     'priority': 'Critical',
#     'due_time': '2026/05/15',
#     'fullname': 'سعید نادری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 3},
#    {'Unnamed: 0': 62,
#     'id': 63,
#     'title': 'بررسی عملکرد مدیران واحدها',
#     'description': 'ارزیابی گزارش های عملکرد',
#     'create_time': '2026-05-04',
#     'status': 'Done',
#     'assignee_id': 13,
#     'priority': 'Low',
#     'due_time': '2026/05/18',
#     'fullname': 'محمدجواد کاظمی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 4},
#    {'Unnamed: 0': 63,
#     'id': 64,
#     'title': 'تهیه گزارش درآمد ماهانه',
#     'description': 'جمع بندی درآمدهای ثبت شده',
#     'create_time': '2026-05-05',
#     'status': 'Done',
#     'assignee_id': 14,
#     'priority': 'Medium',
#     'due_time': '2026/05/20',
#     'fullname': 'لیلا جعفری',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 5},
#    {'Unnamed: 0': 64,
#     'id': 65,
#     'title': 'پیاده سازی API مدیریت فایل',
#     'description': 'افزودن قابلیت آپلود و دانلود فایل',
#     'create_time': '2026-05-06',
#     'status': 'In Progress',
#     'assignee_id': 15,
#     'priority': 'High',
#     'due_time': '2026/06/28',
#     'fullname': 'علی مرادی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 6},
#    {'Unnamed: 0': 65,
#     'id': 66,
#     'title': 'تحلیل بازخورد مشتریان',
#     'description': 'دسته بندی پیشنهادات کاربران',
#     'create_time': '2026-05-07',
#     'status': 'Done',
#     'assignee_id': 16,
#     'priority': 'Medium',
#     'due_time': '2026/05/22',
#     'fullname': 'الهام رستمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 7},
#    {'Unnamed: 0': 66,
#     'id': 67,
#     'title': 'مهاجرت پایگاه داده گزارشات',
#     'description': 'انتقال دیتابیس به سرور جدید',
#     'create_time': '2026-05-08',
#     'status': 'Review',
#     'assignee_id': 17,
#     'priority': 'Critical',
#     'due_time': '2026/06/05',
#     'fullname': 'مجتبی حیدری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 8},
#    {'Unnamed: 0': 67,
#     'id': 68,
#     'title': 'بهبود فرآیند پاسخگویی',
#     'description': 'کاهش زمان پاسخ تیم پشتیبانی',
#     'create_time': '2026-05-09',
#     'status': 'Done',
#     'assignee_id': 18,
#     'priority': 'Medium',
#     'due_time': '2026/05/25',
#     'fullname': 'نگار امینی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 9},
#    {'Unnamed: 0': 68,
#     'id': 69,
#     'title': 'رفع خطای همگام سازی داده ها',
#     'description': 'اصلاح مشکل تبادل اطلاعات',
#     'create_time': '2026-05-10',
#     'status': 'Done',
#     'assignee_id': 19,
#     'priority': 'High',
#     'due_time': '2026/05/17',
#     'fullname': 'احمد صادقی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 10},
#    {'Unnamed: 0': 69,
#     'id': 70,
#     'title': 'بررسی هزینه های عملیاتی',
#     'description': 'تحلیل هزینه سرویس های جاری',
#     'create_time': '2026-05-11',
#     'status': 'Done',
#     'assignee_id': 20,
#     'priority': 'Medium',
#     'due_time': '2026/05/28',
#     'fullname': 'سمیه شریفی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 11},
#    {'Unnamed: 0': 70,
#     'id': 71,
#     'title': 'تهیه گزارش عملکرد فصل بهار',
#     'description': 'ارزیابی خروجی تیم ها',
#     'create_time': '2026-05-12',
#     'status': 'Done',
#     'assignee_id': 21,
#     'priority': 'Low',
#     'due_time': '2026/05/30',
#     'fullname': 'مهدی قنبری',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 12},
#    {'Unnamed: 0': 71,
#     'id': 72,
#     'title': 'طراحی قابلیت یادداشت گذاری',
#     'description': 'تعریف نیازمندی های محصول',
#     'create_time': '2026-05-13',
#     'status': 'Done',
#     'assignee_id': 22,
#     'priority': 'Medium',
#     'due_time': '2026/05/31',
#     'fullname': 'یاسمن کریمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 13},
#    {'Unnamed: 0': 72,
#     'id': 73,
#     'title': 'پیاده سازی جستجوی کاربران',
#     'description': 'افزودن فیلترهای جدید',
#     'create_time': '2026-05-14',
#     'status': 'Review',
#     'assignee_id': 23,
#     'priority': 'High',
#     'due_time': '2026/06/07',
#     'fullname': 'محمد صالحی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 14},
#    {'Unnamed: 0': 73,
#     'id': 74,
#     'title': 'رسیدگی به درخواست های مشتریان کلیدی',
#     'description': 'پیگیری مشکلات ثبت شده',
#     'create_time': '2026-05-15',
#     'status': 'Done',
#     'assignee_id': 24,
#     'priority': 'Medium',
#     'due_time': '2026/05/25',
#     'fullname': 'زینب نوری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 15},
#    {'Unnamed: 0': 74,
#     'id': 75,
#     'title': 'استقرار سرویس احراز هویت',
#     'description': 'انتشار نسخه جدید سرویس',
#     'create_time': '2026-05-16',
#     'status': 'Done',
#     'assignee_id': 25,
#     'priority': 'High',
#     'due_time': '2026/05/29',
#     'fullname': 'امین توکلی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 16},
#    {'Unnamed: 0': 75,
#     'id': 76,
#     'title': 'ممیزی تراکنش های مالی',
#     'description': 'کنترل صحت اطلاعات مالی',
#     'create_time': '2026-05-17',
#     'status': 'Done',
#     'assignee_id': 26,
#     'priority': 'Medium',
#     'due_time': '2026/05/31',
#     'fullname': 'هانیه یوسفی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 17},
#    {'Unnamed: 0': 76,
#     'id': 77,
#     'title': 'بهینه سازی ایندکس های دیتابیس',
#     'description': 'افزایش کارایی کوئری ها',
#     'create_time': '2026-05-18',
#     'status': 'Open',
#     'assignee_id': 27,
#     'priority': 'Critical',
#     'due_time': '2026/06/30',
#     'fullname': 'علیرضا محمدپور',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 18},
#    {'Unnamed: 0': 77,
#     'id': 78,
#     'title': 'تحلیل نرخ بازگشت کاربران',
#     'description': 'بررسی رفتار مشتریان',
#     'create_time': '2026-05-19',
#     'status': 'Done',
#     'assignee_id': 28,
#     'priority': 'Medium',
#     'due_time': '2026/06/02',
#     'fullname': 'پرستو زمانی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 19},
#    {'Unnamed: 0': 78,
#     'id': 79,
#     'title': 'پیاده سازی Queue پردازش',
#     'description': 'ایجاد صف پردازش غیرهمزمان',
#     'create_time': '2026-05-20',
#     'status': 'In Progress',
#     'assignee_id': 29,
#     'priority': 'High',
#     'due_time': '2026/06/25',
#     'fullname': 'آرش دهقانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 20},
#    {'Unnamed: 0': 79,
#     'id': 80,
#     'title': 'بررسی درخواست های معوق',
#     'description': 'اولویت بندی موارد باز',
#     'create_time': '2026-05-21',
#     'status': 'Done',
#     'assignee_id': 30,
#     'priority': 'Medium',
#     'due_time': '2026/05/29',
#     'fullname': 'نسرین باقری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 21},
#    {'Unnamed: 0': 80,
#     'id': 81,
#     'title': 'استقرار سامانه مانیتورینگ لاگ',
#     'description': 'راه اندازی سیستم مشاهده لاگ',
#     'create_time': '2026-05-22',
#     'status': 'Review',
#     'assignee_id': 31,
#     'priority': 'High',
#     'due_time': '2026/06/09',
#     'fullname': 'رضا نیکخواه',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 22},
#    {'Unnamed: 0': 81,
#     'id': 82,
#     'title': 'تهیه پیش بینی بودجه تابستان',
#     'description': 'برآورد هزینه های فصل آینده',
#     'create_time': '2026-05-23',
#     'status': 'Done',
#     'assignee_id': 32,
#     'priority': 'Medium',
#     'due_time': '2026/06/05',
#     'fullname': 'مونا سلیمانی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 23},
#    {'Unnamed: 0': 82,
#     'id': 83,
#     'title': 'بررسی ساختار تیم توسعه',
#     'description': 'ارزیابی نیازهای فنی',
#     'create_time': '2026-05-24',
#     'status': 'Done',
#     'assignee_id': 33,
#     'priority': 'Low',
#     'due_time': '2026/06/10',
#     'fullname': 'حامد اسدی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 24},
#    {'Unnamed: 0': 83,
#     'id': 84,
#     'title': 'طراحی قابلیت مدیریت تیم ها',
#     'description': 'تعریف سناریوهای جدید محصول',
#     'create_time': '2026-05-25',
#     'status': 'Open',
#     'assignee_id': 34,
#     'priority': 'Medium',
#     'due_time': '2026/06/26',
#     'fullname': 'فرزانه رفیعی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 25},
#    {'Unnamed: 0': 84,
#     'id': 85,
#     'title': 'پیاده سازی API اعلان ها',
#     'description': 'توسعه سرویس Notification',
#     'create_time': '2026-05-26',
#     'status': 'In Progress',
#     'assignee_id': 35,
#     'priority': 'High',
#     'due_time': '2026/06/29',
#     'fullname': 'احسان طاهری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 26},
#    {'Unnamed: 0': 85,
#     'id': 86,
#     'title': 'پاسخ به مشتریان راهبردی',
#     'description': 'پیگیری درخواست های سازمانی',
#     'create_time': '2026-05-27',
#     'status': 'Done',
#     'assignee_id': 36,
#     'priority': 'Medium',
#     'due_time': '2026/06/02',
#     'fullname': 'مهسا نعمتی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 27},
#    {'Unnamed: 0': 86,
#     'id': 87,
#     'title': 'استقرار نسخه جدید Backend',
#     'description': 'انتشار تغییرات زیرساختی',
#     'create_time': '2026-05-28',
#     'status': 'Open',
#     'assignee_id': 37,
#     'priority': 'Critical',
#     'due_time': '2026/06/27',
#     'fullname': 'میلاد فتحی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 28},
#    {'Unnamed: 0': 87,
#     'id': 88,
#     'title': 'تهیه گزارش سود و زیان',
#     'description': 'جمع بندی عملکرد مالی',
#     'create_time': '2026-05-29',
#     'status': 'Review',
#     'assignee_id': 38,
#     'priority': 'Medium',
#     'due_time': '2026/06/08',
#     'fullname': 'شیوا محمودی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 29},
#    {'Unnamed: 0': 88,
#     'id': 89,
#     'title': 'رفع خطای پردازش پرداخت',
#     'description': 'اصلاح مشکل در سرویس مالی',
#     'create_time': '2026-05-30',
#     'status': 'Done',
#     'assignee_id': 39,
#     'priority': 'Critical',
#     'due_time': '2026/06/04',
#     'fullname': 'پویا شهبازی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 30},
#    {'Unnamed: 0': 89,
#     'id': 90,
#     'title': 'تحلیل شاخص های محصول',
#     'description': 'بررسی KPI های اصلی',
#     'create_time': '2026-05-31',
#     'status': 'Done',
#     'assignee_id': 40,
#     'priority': 'Medium',
#     'due_time': '2026/06/06',
#     'fullname': 'سحر جلالی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 5,
#     'create_day': 31},
#    {'Unnamed: 0': 90,
#     'id': 91,
#     'title': 'پیاده سازی سیستم مجوزها',
#     'description': 'مدیریت نقش ها و دسترسی ها',
#     'create_time': '2026-06-01',
#     'status': 'Open',
#     'assignee_id': 41,
#     'priority': 'High',
#     'due_time': '2026/07/05',
#     'fullname': 'داوود قربانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 1},
#    {'Unnamed: 0': 91,
#     'id': 92,
#     'title': 'بررسی کیفیت خدمات پشتیبانی',
#     'description': 'تحلیل رضایت مشتریان',
#     'create_time': '2026-06-02',
#     'status': 'In Progress',
#     'assignee_id': 42,
#     'priority': 'Medium',
#     'due_time': '2026/06/30',
#     'fullname': 'محدثه ملکی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 2},
#    {'Unnamed: 0': 92,
#     'id': 93,
#     'title': 'استقرار زیرساخت Kubernetes',
#     'description': 'راه اندازی کلاستر عملیاتی',
#     'create_time': '2026-06-03',
#     'status': 'Open',
#     'assignee_id': 43,
#     'priority': 'Critical',
#     'due_time': '2026/07/10',
#     'fullname': 'مرتضی کریمی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 3},
#    {'Unnamed: 0': 93,
#     'id': 94,
#     'title': 'تهیه گزارش حسابرسی داخلی',
#     'description': 'بررسی اسناد و مدارک',
#     'create_time': '2026-06-04',
#     'status': 'Review',
#     'assignee_id': 44,
#     'priority': 'High',
#     'due_time': '2026/06/20',
#     'fullname': 'نازنین ابراهیمی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 4},
#    {'Unnamed: 0': 94,
#     'id': 95,
#     'title': 'برنامه ریزی جذب نیروهای فنی',
#     'description': 'تعیین ظرفیت های استخدام',
#     'create_time': '2026-06-05',
#     'status': 'Open',
#     'assignee_id': 45,
#     'priority': 'Medium',
#     'due_time': '2026/07/01',
#     'fullname': 'کیوان صادقی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 5},
#    {'Unnamed: 0': 95,
#     'id': 96,
#     'title': 'طراحی سیستم امتیازدهی مشتریان',
#     'description': 'تعریف قواعد کسب و کار',
#     'create_time': '2026-06-06',
#     'status': 'In Progress',
#     'assignee_id': 46,
#     'priority': 'High',
#     'due_time': '2026/07/05',
#     'fullname': 'آرزو حسینی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 6},
#    {'Unnamed: 0': 96,
#     'id': 97,
#     'title': 'توسعه Agent پاسخگوی داخلی',
#     'description': 'پیاده سازی Agent مبتنی بر LLM',
#     'create_time': '2026-06-07',
#     'status': 'Open',
#     'assignee_id': 47,
#     'priority': 'Critical',
#     'due_time': '2026/07/15',
#     'fullname': 'یوسف رحمانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 7},
#    {'Unnamed: 0': 97,
#     'id': 98,
#     'title': 'رسیدگی به تیکت های سطح یک',
#     'description': 'بررسی درخواست های روزانه',
#     'create_time': '2026-06-08',
#     'status': 'Done',
#     'assignee_id': 48,
#     'priority': 'Medium',
#     'due_time': '2026/06/12',
#     'fullname': 'الهه اکبری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 8},
#    {'Unnamed: 0': 98,
#     'id': 99,
#     'title': 'استقرار سرویس پردازش رویداد',
#     'description': 'راه اندازی Event Processing Service',
#     'create_time': '2026-06-09',
#     'status': 'Open',
#     'assignee_id': 49,
#     'priority': 'High',
#     'due_time': '2026/07/08',
#     'fullname': 'بهنام شفیعی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 9},
#    {'Unnamed: 0': 99,
#     'id': 100,
#     'title': 'تهیه گزارش مالی نیم سال اول',
#     'description': 'آماده سازی گزارش مدیریتی',
#     'create_time': '2026-06-10',
#     'status': 'In Progress',
#     'assignee_id': 50,
#     'priority': 'Medium',
#     'due_time': '2026/07/01',
#     'fullname': 'رویا موسوی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 10},
#    {'Unnamed: 0': 100,
#     'id': 101,
#     'title': 'پیاده سازی سیستم Audit Log',
#     'description': 'ثبت رویدادهای حساس کاربران',
#     'create_time': '2026-06-11',
#     'status': 'Open',
#     'assignee_id': 1,
#     'priority': 'High',
#     'due_time': '2026/07/12',
#     'fullname': 'علی صابری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 11},
#    {'Unnamed: 0': 101,
#     'id': 102,
#     'title': 'بهینه سازی Cache سرویس سفارشات',
#     'description': 'کاهش بار پایگاه داده',
#     'create_time': '2026-06-11',
#     'status': 'In Progress',
#     'assignee_id': 2,
#     'priority': 'High',
#     'due_time': '2026/07/05',
#     'fullname': 'رضا محمدی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 11},
#    {'Unnamed: 0': 102,
#     'id': 103,
#     'title': 'طراحی قابلیت آرشیو پروژه ها',
#     'description': 'تعریف نیازمندی ها و سناریوها',
#     'create_time': '2026-06-12',
#     'status': 'Review',
#     'assignee_id': 3,
#     'priority': 'Medium',
#     'due_time': '2026/06/30',
#     'fullname': 'سارا احمدی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 12},
#    {'Unnamed: 0': 103,
#     'id': 104,
#     'title': 'بررسی عملکرد واحدهای سازمان',
#     'description': 'تحلیل شاخص های مدیریتی',
#     'create_time': '2026-06-12',
#     'status': 'Done',
#     'assignee_id': 4,
#     'priority': 'Low',
#     'due_time': '2026/06/20',
#     'fullname': 'محمد رضایی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 12},
#    {'Unnamed: 0': 104,
#     'id': 105,
#     'title': 'پاسخگویی به مشتریان ویژه',
#     'description': 'مدیریت درخواست های VIP',
#     'create_time': '2026-06-13',
#     'status': 'In Progress',
#     'assignee_id': 5,
#     'priority': 'Medium',
#     'due_time': '2026/07/01',
#     'fullname': 'مریم کریمی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 13},
#    {'Unnamed: 0': 105,
#     'id': 106,
#     'title': 'استقرار سرویس مدیریت فایل',
#     'description': 'انتشار نسخه جدید سرویس',
#     'create_time': '2026-06-13',
#     'status': 'Review',
#     'assignee_id': 6,
#     'priority': 'High',
#     'due_time': '2026/06/25',
#     'fullname': 'حسین اکبری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 13},
#    {'Unnamed: 0': 106,
#     'id': 107,
#     'title': 'تهیه گزارش جریان نقدی',
#     'description': 'بررسی وضعیت نقدینگی شرکت',
#     'create_time': '2026-06-14',
#     'status': 'Done',
#     'assignee_id': 7,
#     'priority': 'Medium',
#     'due_time': '2026/06/28',
#     'fullname': 'نرگس حسینی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 14},
#    {'Unnamed: 0': 107,
#     'id': 108,
#     'title': 'پیاده سازی OAuth2',
#     'description': 'افزودن ورود با سرویس های ثالث',
#     'create_time': '2026-06-14',
#     'status': 'Open',
#     'assignee_id': 8,
#     'priority': 'Critical',
#     'due_time': '2026/07/15',
#     'fullname': 'امیر عباسی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 14},
#    {'Unnamed: 0': 108,
#     'id': 109,
#     'title': 'طراحی صفحه مدیریت اعلان ها',
#     'description': 'بهبود تجربه مدیریت پیام ها',
#     'create_time': '2026-06-15',
#     'status': 'Review',
#     'assignee_id': 9,
#     'priority': 'Medium',
#     'due_time': '2026/07/02',
#     'fullname': 'زهرا موسوی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 15},
#    {'Unnamed: 0': 109,
#     'id': 110,
#     'title': 'توسعه API مدیریت کاربران',
#     'description': 'افزودن عملیات مدیریتی جدید',
#     'create_time': '2026-06-15',
#     'status': 'In Progress',
#     'assignee_id': 10,
#     'priority': 'High',
#     'due_time': '2026/07/08',
#     'fullname': 'پیمان قاسمی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 15},
#    {'Unnamed: 0': 110,
#     'id': 111,
#     'title': 'تحلیل دلایل نارضایتی مشتریان',
#     'description': 'بررسی داده های نظرسنجی',
#     'create_time': '2026-06-16',
#     'status': 'Done',
#     'assignee_id': 11,
#     'priority': 'Medium',
#     'due_time': '2026/06/26',
#     'fullname': 'فاطمه رحیمی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 16},
#    {'Unnamed: 0': 111,
#     'id': 112,
#     'title': 'استقرار سامانه پشتیبان گیری',
#     'description': 'راه اندازی Backup خودکار',
#     'create_time': '2026-06-16',
#     'status': 'Open',
#     'assignee_id': 12,
#     'priority': 'High',
#     'due_time': '2026/07/10',
#     'fullname': 'سعید نادری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 16},
#    {'Unnamed: 0': 112,
#     'id': 113,
#     'title': 'برنامه ریزی اهداف فصل پاییز',
#     'description': 'تعیین شاخص های کلیدی',
#     'create_time': '2026-06-17',
#     'status': 'Done',
#     'assignee_id': 13,
#     'priority': 'Low',
#     'due_time': '2026/06/30',
#     'fullname': 'محمدجواد کاظمی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 17},
#    {'Unnamed: 0': 113,
#     'id': 114,
#     'title': 'تهیه گزارش مالی پروژه ها',
#     'description': 'بررسی هزینه و درآمد پروژه ها',
#     'create_time': '2026-06-17',
#     'status': 'Review',
#     'assignee_id': 14,
#     'priority': 'Medium',
#     'due_time': '2026/07/03',
#     'fullname': 'لیلا جعفری',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 17},
#    {'Unnamed: 0': 114,
#     'id': 115,
#     'title': 'پیاده سازی Export اکسل',
#     'description': 'امکان خروجی گرفتن از گزارشات',
#     'create_time': '2026-06-18',
#     'status': 'In Progress',
#     'assignee_id': 15,
#     'priority': 'High',
#     'due_time': '2026/07/10',
#     'fullname': 'علی مرادی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 18},
#    {'Unnamed: 0': 115,
#     'id': 116,
#     'title': 'تحلیل قابلیت های درخواستی مشتریان',
#     'description': 'اولویت بندی نیازمندی ها',
#     'create_time': '2026-06-18',
#     'status': 'Done',
#     'assignee_id': 16,
#     'priority': 'Medium',
#     'due_time': '2026/06/29',
#     'fullname': 'الهام رستمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 18},
#    {'Unnamed: 0': 116,
#     'id': 117,
#     'title': 'مهاجرت سرویس احراز هویت',
#     'description': 'انتقال به زیرساخت جدید',
#     'create_time': '2026-06-19',
#     'status': 'Open',
#     'assignee_id': 17,
#     'priority': 'Critical',
#     'due_time': '2026/07/20',
#     'fullname': 'مجتبی حیدری',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 19},
#    {'Unnamed: 0': 117,
#     'id': 118,
#     'title': 'بهبود فرآیند پاسخگویی تیکت ها',
#     'description': 'کاهش زمان رسیدگی',
#     'create_time': '2026-06-19',
#     'status': 'Done',
#     'assignee_id': 18,
#     'priority': 'Medium',
#     'due_time': '2026/06/30',
#     'fullname': 'نگار امینی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 19},
#    {'Unnamed: 0': 118,
#     'id': 119,
#     'title': 'رفع خطای همزمانی در پرداخت',
#     'description': 'اصلاح Race Condition موجود',
#     'create_time': '2026-06-20',
#     'status': 'Review',
#     'assignee_id': 19,
#     'priority': 'Critical',
#     'due_time': '2026/07/05',
#     'fullname': 'احمد صادقی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 20},
#    {'Unnamed: 0': 119,
#     'id': 120,
#     'title': 'کنترل مغایرت حساب ها',
#     'description': 'بررسی اختلافات مالی ثبت شده',
#     'create_time': '2026-06-20',
#     'status': 'Done',
#     'assignee_id': 20,
#     'priority': 'Medium',
#     'due_time': '2026/07/01',
#     'fullname': 'سمیه شریفی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 20},
#    {'Unnamed: 0': 120,
#     'id': 121,
#     'title': 'بررسی عملکرد مدیران پروژه',
#     'description': 'تحلیل وضعیت پیشرفت پروژه ها',
#     'create_time': '2026-06-21',
#     'status': 'Done',
#     'assignee_id': 21,
#     'priority': 'Low',
#     'due_time': '2026/07/02',
#     'fullname': 'مهدی قنبری',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 21},
#    {'Unnamed: 0': 121,
#     'id': 122,
#     'title': 'طراحی قابلیت اشتراک فایل',
#     'description': 'تعریف نیازمندی های محصول',
#     'create_time': '2026-06-21',
#     'status': 'Open',
#     'assignee_id': 22,
#     'priority': 'Medium',
#     'due_time': '2026/07/15',
#     'fullname': 'یاسمن کریمی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 21},
#    {'Unnamed: 0': 122,
#     'id': 123,
#     'title': 'پیاده سازی فیلترهای پیشرفته',
#     'description': 'افزودن قابلیت های جستجو',
#     'create_time': '2026-06-22',
#     'status': 'In Progress',
#     'assignee_id': 23,
#     'priority': 'High',
#     'due_time': '2026/07/12',
#     'fullname': 'محمد صالحی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 22},
#    {'Unnamed: 0': 123,
#     'id': 124,
#     'title': 'پاسخ به مشتریان سازمانی',
#     'description': 'پیگیری درخواست های ثبت شده',
#     'create_time': '2026-06-22',
#     'status': 'Done',
#     'assignee_id': 24,
#     'priority': 'Medium',
#     'due_time': '2026/07/01',
#     'fullname': 'زینب نوری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 22},
#    {'Unnamed: 0': 124,
#     'id': 125,
#     'title': 'استقرار سرویس گزارش ساز',
#     'description': 'انتشار سرویس در محیط Production',
#     'create_time': '2026-06-23',
#     'status': 'Review',
#     'assignee_id': 25,
#     'priority': 'High',
#     'due_time': '2026/07/04',
#     'fullname': 'امین توکلی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 23},
#    {'Unnamed: 0': 125,
#     'id': 126,
#     'title': 'ممیزی تراکنش های بین سیستمی',
#     'description': 'کنترل تبادل اطلاعات مالی',
#     'create_time': '2026-06-23',
#     'status': 'Done',
#     'assignee_id': 26,
#     'priority': 'Medium',
#     'due_time': '2026/07/05',
#     'fullname': 'هانیه یوسفی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 23},
#    {'Unnamed: 0': 126,
#     'id': 127,
#     'title': 'بهینه سازی Stored Procedure ها',
#     'description': 'کاهش زمان اجرای گزارشات',
#     'create_time': '2026-06-24',
#     'status': 'Open',
#     'assignee_id': 27,
#     'priority': 'Critical',
#     'due_time': '2026/07/18',
#     'fullname': 'علیرضا محمدپور',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 24},
#    {'Unnamed: 0': 127,
#     'id': 128,
#     'title': 'تحلیل نرخ حفظ مشتریان',
#     'description': 'بررسی رفتار بلندمدت کاربران',
#     'create_time': '2026-06-24',
#     'status': 'Done',
#     'assignee_id': 28,
#     'priority': 'Medium',
#     'due_time': '2026/07/03',
#     'fullname': 'پرستو زمانی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 24},
#    {'Unnamed: 0': 128,
#     'id': 129,
#     'title': 'پیاده سازی Event Bus',
#     'description': 'طراحی ارتباط سرویس ها',
#     'create_time': '2026-06-25',
#     'status': 'In Progress',
#     'assignee_id': 29,
#     'priority': 'High',
#     'due_time': '2026/07/20',
#     'fullname': 'آرش دهقانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 25},
#    {'Unnamed: 0': 129,
#     'id': 130,
#     'title': 'بررسی درخواست های پشتیبانی باز',
#     'description': 'اولویت بندی موارد موجود',
#     'create_time': '2026-06-25',
#     'status': 'Done',
#     'assignee_id': 30,
#     'priority': 'Medium',
#     'due_time': '2026/07/02',
#     'fullname': 'نسرین باقری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 25},
#    {'Unnamed: 0': 130,
#     'id': 131,
#     'title': 'استقرار سیستم مانیتورینگ API',
#     'description': 'پایش سلامت سرویس ها',
#     'create_time': '2026-06-26',
#     'status': 'Open',
#     'assignee_id': 31,
#     'priority': 'High',
#     'due_time': '2026/07/16',
#     'fullname': 'رضا نیکخواه',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 26},
#    {'Unnamed: 0': 131,
#     'id': 132,
#     'title': 'تهیه بودجه فصل پاییز',
#     'description': 'پیش بینی هزینه های آتی',
#     'create_time': '2026-06-26',
#     'status': 'Review',
#     'assignee_id': 32,
#     'priority': 'Medium',
#     'due_time': '2026/07/08',
#     'fullname': 'مونا سلیمانی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 26},
#    {'Unnamed: 0': 132,
#     'id': 133,
#     'title': 'ارزیابی ساختار تیم فنی',
#     'description': 'بررسی ظرفیت توسعه تیم',
#     'create_time': '2026-06-27',
#     'status': 'Done',
#     'assignee_id': 33,
#     'priority': 'Low',
#     'due_time': '2026/07/05',
#     'fullname': 'حامد اسدی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 27},
#    {'Unnamed: 0': 133,
#     'id': 134,
#     'title': 'طراحی قابلیت مدیریت مجوزها',
#     'description': 'تعریف سناریوهای دسترسی',
#     'create_time': '2026-06-27',
#     'status': 'Open',
#     'assignee_id': 34,
#     'priority': 'Medium',
#     'due_time': '2026/07/17',
#     'fullname': 'فرزانه رفیعی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 27},
#    {'Unnamed: 0': 134,
#     'id': 135,
#     'title': 'توسعه API تنظیمات سیستم',
#     'description': 'افزودن Endpoint های جدید',
#     'create_time': '2026-06-28',
#     'status': 'In Progress',
#     'assignee_id': 35,
#     'priority': 'High',
#     'due_time': '2026/07/21',
#     'fullname': 'احسان طاهری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 28},
#    {'Unnamed: 0': 135,
#     'id': 136,
#     'title': 'مدیریت درخواست های مشتریان کلیدی',
#     'description': 'پیگیری نیازهای ویژه',
#     'create_time': '2026-06-28',
#     'status': 'Done',
#     'assignee_id': 36,
#     'priority': 'Medium',
#     'due_time': '2026/07/04',
#     'fullname': 'مهسا نعمتی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 28},
#    {'Unnamed: 0': 136,
#     'id': 137,
#     'title': 'استقرار نسخه جدید Frontend',
#     'description': 'انتشار تغییرات رابط کاربری',
#     'create_time': '2026-06-29',
#     'status': 'Review',
#     'assignee_id': 37,
#     'priority': 'High',
#     'due_time': '2026/07/07',
#     'fullname': 'میلاد فتحی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 29},
#    {'Unnamed: 0': 137,
#     'id': 138,
#     'title': 'تهیه گزارش سودآوری مشتریان',
#     'description': 'تحلیل درآمد مشتریان',
#     'create_time': '2026-06-29',
#     'status': 'Done',
#     'assignee_id': 38,
#     'priority': 'Medium',
#     'due_time': '2026/07/10',
#     'fullname': 'شیوا محمودی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 29},
#    {'Unnamed: 0': 138,
#     'id': 139,
#     'title': 'رفع خطای پردازش صورتحساب',
#     'description': 'اصلاح مشکل صدور فاکتور',
#     'create_time': '2026-06-30',
#     'status': 'Open',
#     'assignee_id': 39,
#     'priority': 'Critical',
#     'due_time': '2026/07/12',
#     'fullname': 'پویا شهبازی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 30},
#    {'Unnamed: 0': 139,
#     'id': 140,
#     'title': 'تحلیل عملکرد قابلیت های جدید',
#     'description': 'بررسی میزان استفاده کاربران',
#     'create_time': '2026-06-30',
#     'status': 'Done',
#     'assignee_id': 40,
#     'priority': 'Medium',
#     'due_time': '2026/07/08',
#     'fullname': 'سحر جلالی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 6,
#     'create_day': 30},
#    {'Unnamed: 0': 140,
#     'id': 141,
#     'title': 'پیاده سازی مدیریت نشست کاربران',
#     'description': 'کنترل Session های فعال',
#     'create_time': '2026-07-01',
#     'status': 'In Progress',
#     'assignee_id': 41,
#     'priority': 'High',
#     'due_time': '2026/07/25',
#     'fullname': 'داوود قربانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 1},
#    {'Unnamed: 0': 141,
#     'id': 142,
#     'title': 'بررسی کیفیت پاسخگویی تیم پشتیبانی',
#     'description': 'تحلیل شاخص های SLA',
#     'create_time': '2026-07-01',
#     'status': 'Done',
#     'assignee_id': 42,
#     'priority': 'Medium',
#     'due_time': '2026/07/10',
#     'fullname': 'محدثه ملکی',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 1},
#    {'Unnamed: 0': 142,
#     'id': 143,
#     'title': 'استقرار سامانه CI/CD جدید',
#     'description': 'بهبود فرآیند انتشار نرم افزار',
#     'create_time': '2026-07-02',
#     'status': 'Open',
#     'assignee_id': 43,
#     'priority': 'Critical',
#     'due_time': '2026/07/28',
#     'fullname': 'مرتضی کریمی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 2},
#    {'Unnamed: 0': 143,
#     'id': 144,
#     'title': 'تهیه گزارش انطباق مالی',
#     'description': 'بررسی الزامات حسابرسی',
#     'create_time': '2026-07-02',
#     'status': 'Review',
#     'assignee_id': 44,
#     'priority': 'High',
#     'due_time': '2026/07/14',
#     'fullname': 'نازنین ابراهیمی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 2},
#    {'Unnamed: 0': 144,
#     'id': 145,
#     'title': 'برنامه ریزی جذب کارشناس محصول',
#     'description': 'تعریف نیازهای استخدامی',
#     'create_time': '2026-07-03',
#     'status': 'Done',
#     'assignee_id': 45,
#     'priority': 'Medium',
#     'due_time': '2026/07/15',
#     'fullname': 'کیوان صادقی',
#     'department': 'مدیریت',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 3},
#    {'Unnamed: 0': 145,
#     'id': 146,
#     'title': 'طراحی سیستم امتیازدهی داخلی',
#     'description': 'تعریف شاخص های ارزیابی',
#     'create_time': '2026-07-03',
#     'status': 'Open',
#     'assignee_id': 46,
#     'priority': 'Medium',
#     'due_time': '2026/07/22',
#     'fullname': 'آرزو حسینی',
#     'department': 'محصول',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 3},
#    {'Unnamed: 0': 146,
#     'id': 147,
#     'title': 'توسعه Agent تحلیل گزارشات',
#     'description': 'پیاده سازی Agent مبتنی بر LLM',
#     'create_time': '2026-07-04',
#     'status': 'In Progress',
#     'assignee_id': 47,
#     'priority': 'Critical',
#     'due_time': '2026/07/30',
#     'fullname': 'یوسف رحمانی',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 4},
#    {'Unnamed: 0': 147,
#     'id': 148,
#     'title': 'رسیدگی به تیکت های معوق',
#     'description': 'بستن درخواست های قدیمی',
#     'create_time': '2026-07-04',
#     'status': 'Done',
#     'assignee_id': 48,
#     'priority': 'Medium',
#     'due_time': '2026/07/11',
#     'fullname': 'الهه اکبری',
#     'department': 'پشتیبانی',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 4},
#    {'Unnamed: 0': 148,
#     'id': 149,
#     'title': 'استقرار سرویس پردازش پیام',
#     'description': 'راه اندازی Message Processing Service',
#     'create_time': '2026-07-05',
#     'status': 'Open',
#     'assignee_id': 49,
#     'priority': 'High',
#     'due_time': '2026/07/26',
#     'fullname': 'بهنام شفیعی',
#     'department': 'استقرار',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 5},
#    {'Unnamed: 0': 149,
#     'id': 150,
#     'title': 'تهیه گزارش عملکرد شش ماهه',
#     'description': 'ارائه گزارش مدیریتی',
#     'create_time': '2026-07-05',
#     'status': 'Review',
#     'assignee_id': 50,
#     'priority': 'Medium',
#     'due_time': '2026/07/18',
#     'fullname': 'رویا موسوی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 7,
#     'create_day': 5}]}}

# %% [markdown]
# ## Statistics

# %%
response = TaskAgent.tryInvoke(user_input="چند تسک بحرانی داریم؟",userID="2269w")
# Out:
# User intent in orchestrator Node:Statistics
# LLM response for statistics node:
# time_window=None status=None priority='Critical' fullname=None department=None
# -----api call----------------
# PAYLOAD:
# {'search_criteria': {'priority': 'Critical'}, 'time_window': None}
# <class 'NoneType'>
# 200
# {"count":150,"data":[{"Unnamed: 0":0,"id":1,"title":"رفع باگ ورود کاربران","description":"بررسی و رفع خطای لاگین در نسخه وب","create_time":"2026-01-05","status":"Done","assignee_id":1,"priority":"High","due_time":"2026/01/08","fullname":"علی صابری","department":"فنی","create_year":2026,"create_month":1,"create_day":5},{"Unnamed: 0":1,"id":2,"title":"پیاده سازی API احراز هویت","description":"ایجاد سرویس JWT برای کاربران","create_time":"2026-01-07","status":"Done","assignee_id":2,"priority":"Critical","due_time":"2026/01/15","fullname":"رضا محمدی","department":"فنی","create_year":2026,"create_month":1,"create_day":7},{"Unnamed: 0":2,"id":3,"title":"طراحی داشبورد مدیریت","description":"طراحی اولیه داشبورد مدیران سیستم","create_time":"2026-01-10","status":"In Progress","assignee_id":3,"priority":"High","due_time":"2026/06/15","fullname":"سارا احمدی","department":"محصول","create_year":2026,"create_month":1,"create_day":10},{"Unnamed: 0":3,"id":4,"title":"تهیه گزارش مالی دی ماه","description":"آماده سازی گزارش هزینه های ماهانه","create_time":"2026-01-12","status":"Done","assignee_id":7,"priority":"Medium","due_time":"2026/01/20","fullname":"نرگس حسینی","department":"مالی","create_year":2026,"create_month":1,"create_day":12},{"Unnamed: 0":4,"id":5,"title":"پاسخگویی به تیکت های مشتریان","description":"بررسی تیکت های معوق","create_time":"2026-01-15","status":"Done","assignee_id":5,"priority":"Medium","due_time":"2026/01/18","fullname":"مریم کریمی","department":"پشتیبانی","create_year":2026,"create_month":1,"create_day":15},{"Unnamed: 0":5,"id":6,"title":"استقرار نسخه 2.1","description":"انتشار نسخه جدید روی سرور عملیاتی","create_time":"2026-01-16","status":"Done","assignee_id":6,"priority":"High","due_time":"2026/01/20","fullname":"حسین اکبری","department":"استقرار","create_year":2026,"create_month":1,"create_day":16},{"Unnamed: 0":6,"id":7,"title":"بازنگری Roadmap محصول","description":"بررسی برنامه سه ماه آینده","create_time":"2026-01-20","status":"Done","assignee_id":22,"priority":"High","due_time":"2026/01/30","fullname":"یاسمن کریمی","department":"محصول","create_year":2026,"create_month":1,"create_day":20},{"Unnamed: 0":7,"id":8,"title":"رفع مشکل مصرف حافظه","description":"بهینه سازی Memory Usage سرویس","create_time":"2026-01-21","status":"Done","assignee_id":8,"priority":"Critical","due_time":"2026/01/28","fullname":"امیر عباسی","department":"فنی","create_year":2026,"create_month":1,"create_day":21},{"Unnamed: 0":8,"id":9,"title":"طراحی صفحه پروفایل کاربر","description":"بهبود تجربه کاربری","create_time":"2026-01-22","status":"Review","assignee_id":9,"priority":"Medium","due_time":"2026/06/05","fullname":"زهرا موسوی","department":"محصول","create_year":2026,"create_month":1,"create_day":22},{"Unnamed: 0":9,"id":10,"title":"پیاده سازی سیستم اعلان","description":"ارسال Notification در سیستم","create_time":"2026-01-25","status":"In Progress","assignee_id":10,"priority":"High","due_time":"2026/06/10","fullname":"پیمان قاسمی","department":"فنی","create_year":2026,"create_month":1,"create_day":25},{"Unnamed: 0":10,"id":11,"title":"بررسی شکایات مشتریان","description":"تحلیل و پاسخ به شکایات ثبت شده","create_time":"2026-01-26","status":"Done","assignee_id":11,"priority":"Medium","due_time":"2026/02/01","fullname":"فاطمه رحیمی","department":"پشتیبانی","create_year":2026,"create_month":1,"create_day":26},{"Unnamed: 0":11,"id":12,"title":"استقرار محیط آزمایشی","description":"راه اندازی سرور تست جدید","create_time":"2026-01-28","status":"Done","assignee_id":12,"priority":"Medium","due_time":"2026/02/05","fullname":"سعید نادری","department":"استقرار","create_year":2026,"create_month":1,"create_day":28},{"Unnamed: 0":12,"id":13,"title":"جلسه برنامه ریزی فصلی","description":"هماهنگی اهداف فصل جدید","create_time":"2026-02-01","status":"Done","assignee_id":13,"priority":"Low","due_time":"2026/02/03","fullname":"محمدجواد کاظمی","department":"مدیریت","create_year":2026,"create_month":2,"create_day":1},{"Unnamed: 0":13,"id":14,"title":"کنترل هزینه های ...
# -----api call----------------
# API result: {'count': 150, 'data': [{'Unnamed: 0': 0, 'id': 1, 'title': 'رفع باگ ورود کاربران', 'description': 'بررسی و رفع خطای لاگین در نسخه وب', 'create_time': '2026-01-05', 'status': 'Done', 'assignee_id': 1, 'priority': 'High', 'due_time': '2026/01/08', 'fullname': 'علی صابری', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 5}, {'Unnamed: 0': 1, 'id': 2, 'title': 'پیاده سازی API احراز هویت', 'description': 'ایجاد سرویس JWT برای کاربران', 'create_time': '2026-01-07', 'status': 'Done', 'assignee_id': 2, 'priority': 'Critical', 'due_time': '2026/01/15', 'fullname': 'رضا محمدی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 7}, {'Unnamed: 0': 2, 'id': 3, 'title': 'طراحی داشبورد مدیریت', 'description': 'طراحی اولیه داشبورد مدیران سیستم', 'create_time': '2026-01-10', 'status': 'In Progress', 'assignee_id': 3, 'priority': 'High', 'due_time': '2026/06/15', 'fullname': 'سارا احمدی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 10}, {'Unnamed: 0': 3, 'id': 4, 'title': 'تهیه گزارش مالی دی ماه', 'description': 'آماده سازی گزارش هزینه های ماهانه', 'create_time': '2026-01-12', 'status': 'Done', 'assignee_id': 7, 'priority': 'Medium', 'due_time': '2026/01/20', 'fullname': 'نرگس حسینی', 'department': 'مالی', 'create_year': 2026, 'create_month': 1, 'create_day': 12}, {'Unnamed: 0': 4, 'id': 5, 'title': 'پاسخگویی به تیکت های مشتریان', 'description': 'بررسی تیکت های معوق', 'create_time': '2026-01-15', 'status': 'Done', 'assignee_id': 5, 'priority': 'Medium', 'due_time': '2026/01/18', 'fullname': 'مریم کریمی', 'department': 'پشتیبانی', 'create_year': 2026, 'create_month': 1, 'create_day': 15}, {'Unnamed: 0': 5, 'id': 6, 'title': 'استقرار نسخه 2.1', 'description': 'انتشار نسخه جدید روی سرور عملیاتی', 'create_time': '2026-01-16', 'status': 'Done', 'assignee_id': 6, 'priority': 'High', 'due_time': '2026/01/20', 'fullname': 'حسین اکبری', 'department': 'استقرار', 'create_year': 2026, 'create_month': 1, 'create_day': 16}, {'Unnamed: 0': 6, 'id': 7, 'title': 'بازنگری Roadmap محصول', 'description': 'بررسی برنامه سه ماه آینده', 'create_time': '2026-01-20', 'status': 'Done', 'assignee_id': 22, 'priority': 'High', 'due_time': '2026/01/30', 'fullname': 'یاسمن کریمی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 20}, {'Unnamed: 0': 7, 'id': 8, 'title': 'رفع مشکل مصرف حافظه', 'description': 'بهینه سازی Memory Usage سرویس', 'create_time': '2026-01-21', 'status': 'Done', 'assignee_id': 8, 'priority': 'Critical', 'due_time': '2026/01/28', 'fullname': 'امیر عباسی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 21}, {'Unnamed: 0': 8, 'id': 9, 'title': 'طراحی صفحه پروفایل کاربر', 'description': 'بهبود تجربه کاربری', 'create_time': '2026-01-22', 'status': 'Review', 'assignee_id': 9, 'priority': 'Medium', 'due_time': '2026/06/05', 'fullname': 'زهرا موسوی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 22}, {'Unnamed: 0': 9, 'id': 10, 'title': 'پیاده سازی سیستم اعلان', 'description': 'ارسال Notification در سیستم', 'create_time': '2026-01-25', 'status': 'In Progress', 'assignee_id': 10, 'priority': 'High', 'due_time': '2026/06/10', 'fullname': 'پیمان قاسمی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 25}, {'Unnamed: 0': 10, 'id': 11, 'title': 'بررسی شکایات مشتریان', 'description': 'تحلیل و پاسخ به شکایات ثبت شده', 'create_time': '2026-01-26', 'status': 'Done', 'assignee_id': 11, 'priority': 'Medium', 'due_time': '2026/02/01', 'fullname': 'فاطمه رحیمی', 'department': 'پشتیبانی', 'create_year': 2026, 'create_month': 1, 'create_day': 26}, {'Unnamed: 0': 11, 'id': 12, 'title': 'استقرار محیط آزمایشی', 'description': 'راه اندازی سرور تست جدید', 'create_time': '2026-01-28', 'status': 'Done', 'assignee_id': 12, 'priority': 'Medium', 'due_time': '2026/02/05', 'fullname': 'سعید نادری', 'department': 'استقرار', 'create_year': 2026, 'create_month': 1, 'create_day': 28 ...
# User is asking for statistics about the ticketing system data. And the total found number is 150
# تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.
# کاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.
# کاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:
#
# 1- Statistics - به معنی آماری
# 2- Analytical - تحلیلی
# 3- Search - جستجو
# 4- Operation - به معنی اعمال هرگونه تغییر
#
#
# در صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.
#
# در صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی.
#  اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد.
#  (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)
#
#
# ** Important: and here is the user intent that you receive:
# User is asking for statistics about the ticketing system data. And the total found number is 150
# You should generate an appropriate response to the user based on the conversation history.
#
# Formatted prompt for CHAT node:
# [SystemMessage(content='تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.\nکاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.\nکاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:\n\n1- Statistics - به معنی آماری\n2- Analytical - تحلیلی\n3- Search - جستجو\n4- Operation - به معنی اعمال هرگونه تغییر \n\n\nدر صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.\n\nدر صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی. \n اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد. \n (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)\n\n\n** Important: and here is the user intent that you receive:\nUser is asking for statistics about the ticketing system data. And the total found number is 150\nYou should generate an appropriate response to the user based on the conversation history.\n ', additional_kwargs={}, response_metadata={}), HumanMessage(content='چند تسک بحرانی داریم؟', additional_kwargs={}, response_metadata={}, id='bfe64cdb-1bb8-463c-9ade-f35547d08fe1')]
# LLM response for chat node:
# content=[{'id': 'resp_01ktcb1mggf86r3zjwxbyd2w7c', 'summary': [], 'type': 'reasoning', 'content': [{'text': 'User asks count of critical tasks. Intent is Statistics, total found number is 150. So respond with number.', 'type': 'reasoning_text'}], 'status': 'completed'}, {'type': 'text', 'text': 'در مجموع\u202f150\u202fتسک بحرانی در سیستم تیکتینگ شناسایی شده\u200cاند.', 'annotations': [], 'id': 'msg_01ktcb1mggf87bjjn7pc7vgtxh'}] additional_kwargs={} response_metadata={'id': 'resp_01ktcb1mggf868t033ns11xycq', 'created_at': 1780678185.0, 'metadata': {}, 'model': 'openai/gpt-oss-120b', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b'} id='resp_01ktcb1mggf868t033ns11xycq' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 376, 'output_tokens': 55, 'total_tokens': 431, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 24}}
# Chat response: در مجموع 150 تسک بحرانی در سیستم تیکتینگ شناسایی شده‌اند.
# 2026-06-05 20:19:45,984 [Agent] [INFO] Graph response: {'messages': [HumanMessage(content='چند تسک بحرانی داریم؟', additional_kwargs={}, response_metadata={}, id='bfe64cdb-1bb8-463c-9ade-f35547d08fe1'), AIMessage(content='در مجموع\u202f150\u202fتسک بحرانی در سیستم تیکتینگ شناسایی شده\u200cاند.', additional_kwargs={}, response_metadata={}, id='36fb4f72-321d-4c83-b933-4e06f9d2a41f', tool_calls=[], invalid_tool_calls=[])], 'user_intent': 'Statistics', 'search_criteria': {'priority': 'Critical'}, 'retrieved_data': {'count': 150, 'data': [{'Unnamed: 0': 0, 'id': 1, 'title': 'رفع باگ ورود کاربران', 'description': 'بررسی و رفع خطای لاگین در نسخه وب', 'create_time': '2026-01-05', 'status': 'Done', 'assignee_id': 1, 'priority': 'High', 'due_time': '2026/01/08', 'fullname': 'علی صابری', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 5}, {'Unnamed: 0': 1, 'id': 2, 'title': 'پیاده سازی API احراز هویت', 'description': 'ایجاد سرویس JWT برای کاربران', 'create_time': '2026-01-07', 'status': 'Done', 'assignee_id': 2, 'priority': 'Critical', 'due_time': '2026/01/15', 'fullname': 'رضا محمدی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 7}, {'Unnamed: 0': 2, 'id': 3, 'title': 'طراحی داشبورد مدیریت', 'description': 'طراحی اولیه داشبورد مدیران سیستم', 'create_time': '2026-01-10', 'status': 'In Progress', 'assignee_id': 3, 'priority': 'High', 'due_time': '2026/06/15', 'fullname': 'سارا احمدی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 10}, {'Unnamed: 0': 3, 'id': 4, 'title': 'تهیه گزارش مالی دی ماه', 'description': 'آماده سازی گزارش هزینه های ماهانه', 'create_time': '2026-01-12', 'status': 'Done', 'assignee_id': 7, 'priority': 'Medium', 'due_time': '2026/01/20', 'fullname': 'نرگس حسینی', 'department': 'مالی', 'create_year': 2026, 'create_month': 1, 'create_day': 12}, {'Unnamed: 0': 4, 'id': 5, 'title': 'پاسخگویی به تیکت های مشتریان', 'description': 'بررسی تیکت های معوق', 'create_time': '2026-01-15', 'status': 'Done', 'assignee_id': 5, 'priority': 'Medium', 'due_time': '2026/01/18', 'fullname': 'مریم کریمی', 'department': 'پشتیبانی', 'create_year': 2026, 'create_month': 1, 'create_day': 15}, {'Unnamed: 0': 5, 'id': 6, 'title': 'استقرار نسخه 2.1', 'description': 'انتشار نسخه جدید روی سرور عملیاتی', 'create_time': '2026-01-16', 'status': 'Done', 'assignee_id': 6, 'priority': 'High', 'due_time': '2026/01/20', 'fullname': 'حسین اکبری', 'department': 'استقرار', 'create_year': 2026, 'create_month': 1, 'create_day': 16}, {'Unnamed: 0': 6, 'id': 7, 'title': 'بازنگری Roadmap محصول', 'description': 'بررسی برنامه سه ماه آینده', 'create_time': '2026-01-20', 'status': 'Done', 'assignee_id': 22, 'priority': 'High', 'due_time': '2026/01/30', 'fullname': 'یاسمن کریمی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 20}, {'Unnamed: 0': 7, 'id': 8, 'title': 'رفع مشکل مصرف حافظه', 'description': 'بهینه سازی Memory Usage سرویس', 'create_time': '2026-01-21', 'status': 'Done', 'assignee_id': 8, 'priority': 'Critical', 'due_time': '2026/01/28', 'fullname': 'امیر عباسی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 21}, {'Unnamed: 0': 8, 'id': 9, 'title': 'طراحی صفحه پروفایل کاربر', 'description': 'بهبود تجربه کاربری', 'create_time': '2026-01-22', 'status': 'Review', 'assignee_id': 9, 'priority': 'Medium', 'due_time': '2026/06/05', 'fullname': 'زهرا موسوی', 'department': 'محصول', 'create_year': 2026, 'create_month': 1, 'create_day': 22}, {'Unnamed: 0': 9, 'id': 10, 'title': 'پیاده سازی سیستم اعلان', 'description': 'ارسال Notification در سیستم', 'create_time': '2026-01-25', 'status': 'In Progress', 'assignee_id': 10, 'priority': 'High', 'due_time': '2026/06/10', 'fullname': 'پیمان قاسمی', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 25}, {'Unnamed: 0': 10, 'id': 11, 'title': 'بررسی شکایات مشتریان', 'description': 'تحلیل و پاسخ به شکایات ثبت شده', 'create_time': '2026-01-26', 'status': 'Done', ' ...

# %%
response = TaskAgent.tryInvoke(user_input="چند تسک بحرانی تو ۵ ماه گذشته داریم؟",userID="2269w")
# Out:
# User intent in orchestrator Node:Statistics
# LLM response for statistics node:
# time_window='۵ ماه گذشته' status=None priority='Critical' fullname=None department=None
# ---------Time window extraction needed based on user intent and search criteria.
# Search criteria received in time window extractor node:
# {'time_window': '۵ ماه گذشته', 'status': None, 'priority': 'Critical', 'fullname': None, 'department': None}
# Extracted time window from previous node:
# ۵ ماه گذشته
# LLM response for time window extractor node:
# days=0 months=5 years=0
# -----api call----------------
# PAYLOAD:
# {'search_criteria': {'time_window': '۵ ماه گذشته', 'status': None, 'priority': 'Critical', 'fullname': None, 'department': None}, 'time_window': {'day': 5, 'month': 1, 'year': 2026}}
# <class 'dict'>
# 200
# {"count":1,"data":[{"Unnamed: 0":0,"id":1,"title":"رفع باگ ورود کاربران","description":"بررسی و رفع خطای لاگین در نسخه وب","create_time":"2026-01-05","status":"Done","assignee_id":1,"priority":"High","due_time":"2026/01/08","fullname":"علی صابری","department":"فنی","create_year":2026,"create_month":1,"create_day":5}]}
# -----api call----------------
# API result: {'count': 1, 'data': [{'Unnamed: 0': 0, 'id': 1, 'title': 'رفع باگ ورود کاربران', 'description': 'بررسی و رفع خطای لاگین در نسخه وب', 'create_time': '2026-01-05', 'status': 'Done', 'assignee_id': 1, 'priority': 'High', 'due_time': '2026/01/08', 'fullname': 'علی صابری', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 5}]}
# User is asking for statistics about the ticketing system data. And the total found number is 1
# تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.
# کاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.
# کاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:
#
# 1- Statistics - به معنی آماری
# 2- Analytical - تحلیلی
# 3- Search - جستجو
# 4- Operation - به معنی اعمال هرگونه تغییر
#
#
# در صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.
#
# در صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی.
#  اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد.
#  (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)
#
#
# ** Important: and here is the user intent that you receive:
# User is asking for statistics about the ticketing system data. And the total found number is 1
# You should generate an appropriate response to the user based on the conversation history.
#
# Formatted prompt for CHAT node:
# [SystemMessage(content='تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.\nکاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.\nکاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:\n\n1- Statistics - به معنی آماری\n2- Analytical - تحلیلی\n3- Search - جستجو\n4- Operation - به معنی اعمال هرگونه تغییر \n\n\nدر صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.\n\nدر صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی. \n اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد. \n (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)\n\n\n** Important: and here is the user intent that you receive:\nUser is asking for statistics about the ticketing system data. And the total found number is 1\nYou should generate an appropriate response to the user based on the conversation history.\n ', additional_kwargs={}, response_metadata={}), HumanMessage(content='چند تسک بحرانی تو ۵ ماه گذشته داریم؟', additional_kwargs={}, response_metadata={}, id='aef108c9-6812-44aa-8f62-ea97e5aa0c6b')]
# LLM response for chat node:
# content=[{'id': 'resp_01ktc9fdy9fgtaa5t1a8ffnn7j', 'summary': [], 'type': 'reasoning', 'content': [{'text': 'User asks stats. Total found number is 1. Need to report count.', 'type': 'reasoning_text'}], 'status': 'completed'}, {'type': 'text', 'text': 'در مجموع\u202f1\u202fتسک بحرانی در\u202f۵\u202fماه گذشته ثبت شده است.', 'annotations': [], 'id': 'msg_01ktc9fdy9fgtrkg4kagctp3bz'}] additional_kwargs={} response_metadata={'id': 'resp_01ktc9fdy9fgss29y6stckzvvs', 'created_at': 1780676540.0, 'metadata': {}, 'model': 'openai/gpt-oss-120b', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b'} id='resp_01ktc9fdy9fgss29y6stckzvvs' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 381, 'output_tokens': 46, 'total_tokens': 427, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 17}}
# Chat response: در مجموع 1 تسک بحرانی در ۵ ماه گذشته ثبت شده است.
# 2026-06-05 19:52:20,908 [Agent] [INFO] Graph response: {'messages': [HumanMessage(content='چند تسک بحرانی تو ۵ ماه گذشته داریم؟', additional_kwargs={}, response_metadata={}, id='aef108c9-6812-44aa-8f62-ea97e5aa0c6b'), AIMessage(content='در مجموع\u202f1\u202fتسک بحرانی در\u202f۵\u202fماه گذشته ثبت شده است.', additional_kwargs={}, response_metadata={}, id='8742872c-d009-4219-95f3-887da331c6c2', tool_calls=[], invalid_tool_calls=[])], 'user_intent': 'Statistics', 'search_criteria': {'time_window': '۵ ماه گذشته', 'status': None, 'priority': 'Critical', 'fullname': None, 'department': None}, 'time_window': {'day': 5, 'month': 1, 'year': 2026}, 'retrieved_data': {'count': 1, 'data': [{'Unnamed: 0': 0, 'id': 1, 'title': 'رفع باگ ورود کاربران', 'description': 'بررسی و رفع خطای لاگین در نسخه وب', 'create_time': '2026-01-05', 'status': 'Done', 'assignee_id': 1, 'priority': 'High', 'due_time': '2026/01/08', 'fullname': 'علی صابری', 'department': 'فنی', 'create_year': 2026, 'create_month': 1, 'create_day': 5}]}}

# %%
response
# Out:
# {'messages': [HumanMessage(content='چند تسک بحرانی تو ۵ ماه گذشته داریم؟', additional_kwargs={}, response_metadata={}, id='aef108c9-6812-44aa-8f62-ea97e5aa0c6b'),
#   AIMessage(content='در مجموع\u202f1\u202fتسک بحرانی در\u202f۵\u202fماه گذشته ثبت شده است.', additional_kwargs={}, response_metadata={}, id='8742872c-d009-4219-95f3-887da331c6c2', tool_calls=[], invalid_tool_calls=[])],
#  'user_intent': 'Statistics',
#  'search_criteria': {'time_window': '۵ ماه گذشته',
#   'status': None,
#   'priority': 'Critical',
#   'fullname': None,
#   'department': None},
#  'time_window': {'day': 5, 'month': 1, 'year': 2026},
#  'retrieved_data': {'count': 1,
#   'data': [{'Unnamed: 0': 0,
#     'id': 1,
#     'title': 'رفع باگ ورود کاربران',
#     'description': 'بررسی و رفع خطای لاگین در نسخه وب',
#     'create_time': '2026-01-05',
#     'status': 'Done',
#     'assignee_id': 1,
#     'priority': 'High',
#     'due_time': '2026/01/08',
#     'fullname': 'علی صابری',
#     'department': 'فنی',
#     'create_year': 2026,
#     'create_month': 1,
#     'create_day': 5}]}}

# %%
response = TaskAgent.tryInvoke(user_input="مربوط به کیه؟",userID="226w")
# Out:
# User intent in orchestrator Node:Search
# <class 'agent_src.basemodels.SearchNodeOutput'>
# {}
# -----api call----------------
# PAYLOAD:
# {'search_criteria': {'create_time': None, 'status': None, 'priority': None, 'due_time': None, 'fullname': None, 'department': None}, 'time_window': {'day': 5, 'month': 4, 'year': 2026}}
# <class 'dict'>
# 200
# {"count":1,"data":[{"Unnamed: 0":43,"id":44,"title":"تهیه گزارش حسابرسی","description":"جمع بندی مستندات مالی","create_time":"2026-04-05","status":"Review","assignee_id":44,"priority":"High","due_time":"2026/06/06","fullname":"نازنین ابراهیمی","department":"مالی","create_year":2026,"create_month":4,"create_day":5}]}
# -----api call----------------
# API result: {'count': 1, 'data': [{'Unnamed: 0': 43, 'id': 44, 'title': 'تهیه گزارش حسابرسی', 'description': 'جمع بندی مستندات مالی', 'create_time': '2026-04-05', 'status': 'Review', 'assignee_id': 44, 'priority': 'High', 'due_time': '2026/06/06', 'fullname': 'نازنین ابراهیمی', 'department': 'مالی', 'create_year': 2026, 'create_month': 4, 'create_day': 5}]}
# User is asking for Search about the ticketing system data. And the total found number is 1
# تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.
# کاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.
# کاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:
#
# 1- Statistics - به معنی آماری
# 2- Analytical - تحلیلی
# 3- Search - جستجو
# 4- Operation - به معنی اعمال هرگونه تغییر
#
#
# در صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.
#
# در صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی.
#  اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد.
#  (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)
#
#
# ** Important: and here is the user intent that you receive:
# User is asking for Search about the ticketing system data. And the total found number is 1
# You should generate an appropriate response to the user based on the conversation history.
#
# Formatted prompt for CHAT node:
# [SystemMessage(content='تو یک مدل هستی که وظیفه داری به سوالات و درخواست های کاربران پاسخ بدی.\nکاربر در مورد داده های موجود در یک دیتابیس مربوط به سامانه تیکتینگ ticketing است.\nکاربر ممکن است یکی از وظایف زیر را برای ما مشخث کرده باشد:\n\n1- Statistics - به معنی آماری\n2- Analytical - تحلیلی\n3- Search - جستجو\n4- Operation - به معنی اعمال هرگونه تغییر \n\n\nدر صورتی که قصد کاربر هیچکدام از آنها نباشد باید به کاربر بگی که متوجه نشدی و ازش بخواهی که سوالش را واضح تر بیان کند یا اطلاعات بیشتری بدهد تا بتوانی بهتر کمکش کنی.\n\nدر صورتی که قصد کاربر برابر با Statistics باشد باید تعداد تسک های پیدا شده را با توجه به سوالی که پرسیده به وی گزارش دهی. \n اما در صورتی که صرفا جست و جو Search  باشد باید صرفا بگی که موارد پیدا شده برایتان ارسال شد. \n (وظیفه ارسال بر عهده تو نیست. فقط باید بگی که موارد پیدا شده برای کاربر ارسال شد.)\n\n\n** Important: and here is the user intent that you receive:\nUser is asking for Search about the ticketing system data. And the total found number is 1\nYou should generate an appropriate response to the user based on the conversation history.\n ', additional_kwargs={}, response_metadata={}), HumanMessage(content='چند تسک حیاتی تو دوماه گذشته داریم؟', additional_kwargs={}, response_metadata={}, id='dcec11d6-25f3-4323-9572-97f9dbe83dc3'), AIMessage(content='در دو ماه گذشته\u202f۱\u202fتسک حیاتی شناسایی شد.', additional_kwargs={}, response_metadata={}, id='8fb337e1-ae6d-4077-b2a2-7005c845042a', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='مربوط به کیه؟', additional_kwargs={}, response_metadata={}, id='6ae9911f-ffd7-45a8-88d7-2234495c4fd7')]
# LLM response for chat node:
# content=[{'id': 'resp_01ktc9ckfjfqvanvma6yte7218', 'summary': [], 'type': 'reasoning', 'content': [{'text': 'User asks "مربوط به کیه؟" likely wants who is the owner. This is operation? It\'s a query about details. Probably Search? They want info about the found task. We can respond that the item was sent. According to guidelines, for Search just say items sent.', 'type': 'reasoning_text'}], 'status': 'completed'}, {'type': 'text', 'text': 'موارد پیدا شده برای شما ارسال شد.', 'annotations': [], 'id': 'msg_01ktc9ckfjfqvvbf3n096q719m'}] additional_kwargs={} response_metadata={'id': 'resp_01ktc9ckfjfqtrpwhyznmkgqch', 'created_at': 1780676447.0, 'metadata': {}, 'model': 'openai/gpt-oss-120b', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b'} id='resp_01ktc9ckfjfqtrpwhyznmkgqch' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 414, 'output_tokens': 78, 'total_tokens': 492, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}
# Chat response: موارد پیدا شده برای شما ارسال شد.
# 2026-06-05 19:50:48,200 [Agent] [INFO] Graph response: {'messages': [HumanMessage(content='چند تسک حیاتی تو دوماه گذشته داریم؟', additional_kwargs={}, response_metadata={}, id='dcec11d6-25f3-4323-9572-97f9dbe83dc3'), AIMessage(content='در دو ماه گذشته\u202f۱\u202fتسک حیاتی شناسایی شد.', additional_kwargs={}, response_metadata={}, id='8fb337e1-ae6d-4077-b2a2-7005c845042a', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='مربوط به کیه؟', additional_kwargs={}, response_metadata={}, id='6ae9911f-ffd7-45a8-88d7-2234495c4fd7'), AIMessage(content='موارد پیدا شده برای شما ارسال شد.', additional_kwargs={}, response_metadata={}, id='b70b1c09-bdd1-482e-a95f-b246cd344ab8', tool_calls=[], invalid_tool_calls=[])], 'user_intent': 'Search', 'search_criteria': {'create_time': None, 'status': None, 'priority': None, 'due_time': None, 'fullname': None, 'department': None}, 'time_window': {'day': 5, 'month': 4, 'year': 2026}, 'retrieved_data': {'count': 1, 'data': [{'Unnamed: 0': 43, 'id': 44, 'title': 'تهیه گزارش حسابرسی', 'description': 'جمع بندی مستندات مالی', 'create_time': '2026-04-05', 'status': 'Review', 'assignee_id': 44, 'priority': 'High', 'due_time': '2026/06/06', 'fullname': 'نازنین ابراهیمی', 'department': 'مالی', 'create_year': 2026, 'create_month': 4, 'create_day': 5}]}}

# %%
response
# Out:
# {'messages': [HumanMessage(content='چند تسک حیاتی تو دوماه گذشته داریم؟', additional_kwargs={}, response_metadata={}, id='dcec11d6-25f3-4323-9572-97f9dbe83dc3'),
#   AIMessage(content='در دو ماه گذشته\u202f۱\u202fتسک حیاتی شناسایی شد.', additional_kwargs={}, response_metadata={}, id='8fb337e1-ae6d-4077-b2a2-7005c845042a', tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='مربوط به کیه؟', additional_kwargs={}, response_metadata={}, id='6ae9911f-ffd7-45a8-88d7-2234495c4fd7'),
#   AIMessage(content='موارد پیدا شده برای شما ارسال شد.', additional_kwargs={}, response_metadata={}, id='b70b1c09-bdd1-482e-a95f-b246cd344ab8', tool_calls=[], invalid_tool_calls=[])],
#  'user_intent': 'Search',
#  'search_criteria': {'create_time': None,
#   'status': None,
#   'priority': None,
#   'due_time': None,
#   'fullname': None,
#   'department': None},
#  'time_window': {'day': 5, 'month': 4, 'year': 2026},
#  'retrieved_data': {'count': 1,
#   'data': [{'Unnamed: 0': 43,
#     'id': 44,
#     'title': 'تهیه گزارش حسابرسی',
#     'description': 'جمع بندی مستندات مالی',
#     'create_time': '2026-04-05',
#     'status': 'Review',
#     'assignee_id': 44,
#     'priority': 'High',
#     'due_time': '2026/06/06',
#     'fullname': 'نازنین ابراهیمی',
#     'department': 'مالی',
#     'create_year': 2026,
#     'create_month': 4,
#     'create_day': 5}]}}

# %%
time_window = response.get("search_criteria", {}).get("time_window")
print (f"Extracted time window: {time_window}")
# Out:
# Extracted time window: دوماه گذشته
