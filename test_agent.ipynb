# %%
import agent_src.agent as agent
TaskAgent = agent.Agent()
# Out:
# 2026-06-02 19:04:44,893 [Agent] [INFO] Graph compiled successfully.

# %%
TaskAgent.tryInvoke(user_input="hello, what are you?")
# Out:
# {'messages': [HumanMessage(content='hello, what are you?', additional_kwargs={}, response_metadata={}, id='0cdfd6ad-b923-4136-a25f-cce29d9a3cc9'),
#   AIMessage(content=[{'id': 'resp_01kt4fj5p5er2ts9ze4cdhs8he', 'summary': [], 'type': 'reasoning', 'content': [{'text': 'We need to respond as ChatGPT.', 'type': 'reasoning_text'}], 'status': 'completed'}, {'type': 'text', 'text': 'I’m ChatGPT, an AI language model created by OpenAI. I can understand and generate text, answer questions, help with writing, explain concepts, brainstorm ideas, and much more. How can I assist you today?', 'annotations': [], 'id': 'msg_01kt4fj5p5er3989gfeqbhwnbp'}], additional_kwargs={}, response_metadata={'id': 'resp_01kt4fj5p5er2aratxcwwjemn3', 'created_at': 1780414486.0, 'metadata': {}, 'model': 'openai/gpt-oss-120b', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'openai/gpt-oss-120b'}, id='resp_01kt4fj5p5er2aratxcwwjemn3', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 77, 'output_tokens': 63, 'total_tokens': 140, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 9}})]}
