# %%
import agent_src.agent as agent
TaskAgent = agent.Agent()
# Out:
# 2026-06-03 00:21:38,396 [Agent] [INFO] Graph compiled successfully.

# %%
response = TaskAgent.tryInvoke(user_input="تسک های احمدی چیان؟",userID="2w")

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined

# %%
response.get("messages")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response.get("messages")
#
# NameError: name 'response' is not defined
