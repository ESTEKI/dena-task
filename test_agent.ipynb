# %%
import graph
TaskAgent = graph.Agent()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import graph
# ----> 2 TaskAgent = graph.Agent()
#
# File c:\Users\estek\Projects\Dena-data\dena-task\graph.py:26, in Agent.__init__(self)
#      23 logger = Logger.LoggerManager("task_agent")
#      24 checkpointer = InMemorySaver()
# ---> 26 graph_builder = StateGraph(NODES.AppState)
#      27 graph_builder.add_node("chatbot",self.nodes.chatbot)
#      28 #graph_builder.add_node("tools", self.nodes.tool_node)
#
# AttributeError: module 'agent.nodes' has no attribute 'AppState'
